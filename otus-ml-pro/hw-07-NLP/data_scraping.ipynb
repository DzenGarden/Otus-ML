# %% [markdown]
# ## Домашнее задание
#
# Откуда берутся датасеты? Практический проект по сбору данных и работе с текстами
#
# Цель:
#
# В этом домашнем задании вам предстоит обойти все ловушки серверов, пробраться сквозь страницы html-код, собрать себе свой собственный датасет и натренировать на нём модель.
#
# ## Часть 1. Парсинг.
#
#
# По аналогии с занятием, возьмите интересующий вас сайт, на котором можно пособирать какие-то данные (и при этом API не предоставляется).
#
#
# Идеальный датасет должен иметь текстовое описание некоторого объекта и некоторую целевую переменную, соответствующую этому объекту. Например:
#
# - Сайт новостей: текстовое описание - сама новость, целевая переменная - количество просмотров новости (можно поделить на число дней с момента даты публикации, чтобы получить “среднее число просмотров в день”).
# - Сайт с товарами/книгами/фильмами: текстовое описание товара/книги/фильма + средний рейтинг в качестве целевой переменной.
# - Блоги - тексты заметок + число просмотров.
# - И любые другие ваши идеи, которые подходят под такой формат.
#
# Напишите свой парсер, который будет бегать по страничкам и автоматически что-то собирать.
# Не забывайте, что парсинг - это ответственное мероприятие, поэтому не бомбардируйте несчастные сайты слишком частыми запросами (можно ограничить число запросов в секунду при помощи time.sleep(0.3), вставленного в теле цикла)

# %%
import requests      # Библиотека для отправки запросов
import numpy as np   
import pandas as pd  
import time          

import warnings
warnings.filterwarnings("ignore")

from fake_useragent import UserAgent
from bs4 import BeautifulSoup
from tqdm import tqdm

# %% [markdown]
# Пакет **[bs4 , a.k.a BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/)** (тут есть гиперссылка на лучшего друга человека — документацию) был назван в честь стишка про красивый суп из Алисы в стране чудес.
#
# Красивый суп — это совершенно волшебная библиотека, которая из сырого и необработанного HTML кода страницы выдаст вам структурированный массив данных, по которому очень удобно искать необходимые теги, классы, атрибуты, тексты и прочие элементы веб страниц.
#
# > Пакет под названием BeautifulSoup — скорее всего, не то, что нам нужно. Это третья версия (Beautiful Soup 3), а мы будем использовать четвертую. Нужно будет установить пакет beautifulsoup4. Чтобы было совсем весело, при импорте нужно указывать другое название пакета — bs4, а импортировать функцию под названием BeautifulSoup. В общем, сначала легко запутаться, но эти трудности нужно преодолеть.
#
# С необработанным XML кодом страницы пакет также работает (XML — это исковерканый и превращённый в диалект, с помощью своих команд, HTML). Для того, чтобы пакет корректно работал с XML разметкой, придётся в довесок ко всему нашему арсеналу установить пакет xml.

# %% [markdown]
# Собирать данные будем на новостном сайте Nice Matin - утренняя Ницца )

# %%
top_page = 'https://www.nicematin.com/'

# %%
UserAgent().chrome
# Out:
# 'Mozilla/5.0 (Linux; Android 10; K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Mobile Safari/537.36'

# %%
top_response = requests.get(top_page, headers={'User-Agent': UserAgent().chrome})
top_response
# Out:
# <Response [200]>

# %%
top_html = top_response.content

# %%
len(top_html)
# Out:
# 273989

# %%
top_soup = BeautifulSoup(top_html, 'html.parser')

# %%
print(top_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="nm" lang="fr">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="icon" type="image/png"/>
#   <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon"/>
#   <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="57x57">
#    <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="60x60">
#     <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="72x72"/>
#     <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="76x76"/>
#     <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="114x114"/>
#     <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="120x120"/>
#     <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="144x144"/>
#     <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="152x152"/>
#     <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="180x180"/>
#     <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="icon" sizes="192x192" type="image/png"/>
#     <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="icon" sizes="32x32" type="image/png"/>
#     <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="icon" sizes="96x96" type="image/png"/>
#     <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="icon" sizes="16x16" type="image/png"/>
#     <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#     <title>
#      Actualités et infos en direct - Nice-Matin
#     </title>
#     <link href="https://fonts.googleapis.com" rel="preconnect"/>
#     <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
#     <link href="https://fonts.googleapis.com/css2?family=Raleway:ital,wght@0,300;0,400;0,500;0,600;0,700;0,900;1,300;1,400;1,500;1,600;1,700;1,900&amp;display=swap" rel="stylesheet"/>
#     <link href="https://fonts.googleapis.com/css2?family=Inter:wght@200;300;400;500;600;700;900&amp;display=swap" rel="stylesheet"/>
#     <link href="https://fonts.googleapis.com/css2?family=Sanchez:ital@0;1&amp;display=swap" rel="stylesheet"/>
#     <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700;900&amp;display=swap" rel="stylesheet"/>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto+Condensed:ital,wght@0,300;0,400;0,700;1,300;1,400;1,700&amp;display=swap" rel="stylesheet"/>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@300;400;500;700;900&amp;display=swap" rel="stylesheet"/>
#     <meta content="index, follow" name="robots"/>
#     <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots">
#      <link href="https://www.nicematin.com" rel="canonical"/>
#      <meta content="Retrouvez toute l'actualité en direct et en vidéo avec le premier quotidien d'informations du Sud-Est." name="description">
#       <script type="text/javascript">
#        var dfpVars = {"enabled":true,"debug":false,"test":false,"lazy":false,"version_beta":false,"responsive":true,"network_id":"31755961,49811762","page_type":"home","level1":"nicematin","level2":"DYNAMIC","level3":"home","level4":"","level5":""};
# var dfpPositions = [];
# var dfpSizes = [];
# var dfpPageTypes = [];
# var dfpTargeting = {"GrNM_connected":"no","GrNM_subscriber_digital":"no","GrNM_subscriber_print":"no"};
#       </script>
#       <script type="text/javascript">
#        var smartAdServerConf = {"network_id":3944,"site_id":430463,"page_id":{"desktop":1412269,"mobile":1412272},"formats":{"desktop":[{"id":97819,"tagId":"div-ps-ad-banniere_basse"},{"id":103881,"tagId":"div-ps-ad-banniere_basse2"},{"id":103882,"tagId":"div-ps-ad-banniere_basse3"},{"id":97818,"tagId":"div-ps-ad-banniere_haute"},{"id":97817,"tagId":"div-ps-ad-pave_bas"},{"id":103884,"tagId":"div-ps-ad-pave_bas2"},{"id":97815,"tagId":"div-ps-ad-pave_haut"},{"id":103883,"tagId":"div-ps-ad-rectangle169eme"}],"mobile":[{"id":97818,"tagId":"div-ps-ad-banniere_haute"},{"id":97817,"tagId":"div-ps-ad-pave_bas"},{"id":103884,"tagId":"div-ps-ad-pave_bas2"},{"id":103890,"tagId":"div-ps-ad-pave_bas3"},{"id":103891,"tagId":"div-ps-ad-pave_bas4"},{"id":111807,"tagId":"div-ps-ad-pave_haut-mobile"}]},"target":"GrNM_connected=no;GrNM_subscriber_digital=no;GrNM_subscriber_print=no;version_beta=false"}
#       </script>
#       <script type="text/javascript">
#        var _sf_async_config = _sf_async_config || {};
#         /** CONFIGURATION START **/
#         _sf_async_config.uid = 65758;
#         _sf_async_config.domain = 'nicematin.com';
#         _sf_async_config.path =  window.location.pathname;
#                 /** CONFIGURATION END **/
#         var _sf_startpt = (new Date()).getTime();
#       </script>
#       <script async="" src="//static.chartbeat.com/js/chartbeat_mab.js">
#       </script>
#       <link href="https://cdn.assets02.nicematin.com/build/css/common/modalNonSubscriber.d838afb8.css" rel="stylesheet"/>
#       <link href="https://cdn.assets03.nicematin.com/build/css/freemium.a6dc255d.css" rel="stylesheet"/>
#       <script type="text/javascript">
#        window.dataLayer = window.dataLayer || [];
#           dataLayer.push({
#             'user_id': null,
#             'user_id_email': null,
#             'user_is_connected': 'false',
#             'environnement': 'prod',
#             'user_is_subscriber': 'false',
#             'espace_client': null,
#             'profil_abo': null,
#             'offre_commercial': null,
#             'date_first_connexion_ec': null,
#             'list_name': null,
#                 'page_template': 'homepage',
#           });
#       </script>
#       <!-- Google Tag Manager -->
#       <script>
#        (function (w, d, s, l, i) {
#     w[l] = w[l] || [];
#     w[l].push({
#       'gtm.start':
#         new Date().getTime(), event: 'gtm.js'
#     });
#     var f = d.getElementsByTagName(s)[0],
#       j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#     j.async = true;
#     j.src =
#       'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#     f.parentNode.insertBefore(j, f);
#   })(window, document, 'script', 'dataLayer', 'GTM-MNNXJVMD');
#       </script>
#       <!-- End Google Tag Manager -->
#       <script crossorigin="anonymous" integrity="sha256-o88AwQnZB+VDvE9tvIXrMQaPlFFSUTR+nldQm1LuPXQ=" src="https://code.jquery.com/jquery-3.6.1.min.js">
#       </script>
#       <script type="text/javascript">
#        document.addEventListener("DOMContentLoaded", function () {
#
#     function datalayerPush(click = "", click_chapter1 = "", click_chapter2 = "") {
#       window.dataLayer.push({
#         event: "user_action", // user_action
#         click: click, // key name
#         click_chapter1: click_chapter1, // url - chapt1 (AT)
#         click_chapter2: click_chapter2, // label - chapt2 (AT)
#       });
#     }
#
#     function selectorEvent(selector, callback, trigger = "click") {
#       let element = document.querySelectorAll(selector);
#       element.forEach((data) => data.addEventListener(trigger, callback));
#     }
#
#     // Clicks Header
#     const linkHeader = document.querySelectorAll("#menu-header a");
#     const linkHeaderFirstLevel = document.querySelectorAll("span.heading-title");
#
#     if (linkHeader) {
#       linkHeader.forEach(e => e.addEventListener("click", function (event) {
#         trackingHeaderLink(event);
#       }));
#     }
#
#     if (linkHeaderFirstLevel) {
#       linkHeaderFirstLevel.forEach(e => e.addEventListener("click", function (event) {
#         trackingHeaderLink(event);
#       }));
#     }
#
#     function trackingHeaderLink(event) {
#       let eventName, eventAction, eventLabel; // Declare variables here
#
#       if(event.currentTarget.classList.contains("article-title")) {
#         // Click on article title
#         eventName = event.currentTarget.getAttribute("data-target") || 'click_article_preview_title';
#         eventAction = event.currentTarget.href;
#         eventLabel =  event.currentTarget.className;
#       } else if(event.currentTarget.classList.contains("header-article-preview")){
#         // Click on article image
#         eventName = event.currentTarget.getAttribute("data-target") || 'click_article_preview_image';
#         eventAction = event.currentTarget.href;
#         eventLabel = event.currentTarget.className;
#       } else if(event.currentTarget.classList.contains("item-journal")) {
#         // Click on newspaper item
#         eventName = "newspaper_header";
#         eventAction = event.currentTarget.href;
#         eventLabel = event.currentTarget.className;
#       } else {
#         // All others links
#         eventName = event.target.innerText.toLowerCase();
#         eventName = eventName.charAt(0).toUpperCase() + eventName.slice(1);
#         eventAction = event.target.href;
#         eventLabel =  event.target.className;
#       }
#       datalayerPush(eventName, eventAction, eventLabel);
#     }
#
#     // Clicks Burger
#     selectorEvent(
#       "#menu-burger-wrapper .menu-burger-links a",
#       (e) => {
#         let eventName = e.target.innerText || 'click_burger';
#         datalayerPush(eventName, e.target.href, e.target.className)
#       }
#     );
#
#     function handleMenuItemClick(level, chapter2) {
#       return function (event) {
#         if (event.target.dataset.level === level) {
#           window.dataLayer.push({
#             'event': 'user_action',
#             'click': 'Burger_link',
#             'click_chapter1': event.target.innerText || '',
#             'click_chapter2': chapter2
#           });
#         }
#       };
#     }
#
#     for (let level = 1; level <= 4; level++) {
#       const strLvl = {1: "first", 2: "second", 3: "third", 4: "fourth"}
#       const niveau = document.querySelectorAll(`.menu-burger-submenu .menu-burger-submenu--${strLvl[level]}_level`);
#       if (niveau) {
#         niveau.forEach((e) => {
#           e.addEventListener('click', handleMenuItemClick(`level-${strLvl[level]}`, `Burger_link_${strLvl[level]}`));
#         });
#       }
#     }
#
#     // Clicks Footer
#     selectorEvent(
#       "#footer a",
#       (e) => {
#         let eventName = e.target.innerText || 'click_footer';
#         datalayerPush(eventName, e.target.href, e.target.className)
#       }
#     );
#
#     // Clicks Articles
#     selectorEvent(
#       "#article-info a",
#       (e) => {
#         let eventName = e.target.innerText || 'click_article';
#         datalayerPush(eventName, e.target.href, e.target.className)
#       }
#     );
#
#     // Clicks Une Burger
#     selectorEvent(
#       "#menu-burger-wrapper .menu-burger-newspaper a",
#       (e) => {
#         datalayerPush("newspaper_burger", e.currentTarget.href, e.currentTarget.className)
#       }
#     );
#   });
#       </script>
#       <script src="https://cdn.assets03.nicematin.com/build/runtime.4b9cb7aa.js">
#       </script>
#       <script src="https://cdn.assets01.nicematin.com/build/8943.cc742ecb.js">
#       </script>
#       <script src="https://cdn.assets02.nicematin.com/build/js/freemium/datalayer.a9ad865c.js">
#       </script>
#       <script type="text/javascript">
#        var userDataLayer = []
# dataLayer.push(userDataLayer);
#       </script>
#       <!-- AB Tasty -->
#       <script src="https://try.abtasty.com/603827b25c3d5d62f85ee3425eea0ee9.js" type="text/javascript">
#       </script>
#       <!-- END AB Tasty -->
#       <script type="text/javascript">
#        var batchConf = {
#             serviceWorkerPathOverride: "/build/js/batchsdk-worker-loader.js",
#             apiKey: 'C424BC1EF90948AAB4419825D0C2E902',
#             subdomain: 'nicematin',
#             authKey: '2.nS7fXyXSnhDa/eA7piks08epgmD/B3H2prtlZhX4UEU=',
#                         vapidPublicKey: 'BJ63KPHtpzS624s81gkgAFuIYzfNAOlPAObJIZ3ACyNDmusYQzo2Ft8gLKOjZCytsCkOPAhlTKDb1+XxFgaTMBU='
#         };
#         var batchCustomerUserId = null;
#       </script>
#       <meta content="nicematin" name="pbstck_context:site_name">
#        <meta content="no" name="pbstck_context:paywall"/>
#        <meta content="no" name="ad:version_beta"/>
#        <meta content="home" name="pbstck_context:page_type"/>
#        <meta content="no" name="ad:GrNM_connected"/>
#        <meta content="no" name="ad:GrNM_subscriber_digital"/>
#        <meta content="no" name="ad:GrNM_subscriber_print"/>
#        <script>
#         let metaDevice = document.createElement('meta');
#   metaDevice.name = "pbstck_context:device";
#   metaDevice.content = screen.width <= 1024 ? "webmobile" : "desktop";
#   document.head.appendChild(metaDevice)
#        </script>
#        <script type="text/javascript">
#         window.dataLayer = window.dataLayer || [];
# const nmDataLayerNavigation = screen.width <= 1024 ? {navigation: "webmobile"} : {navigation: "desktop"};
# const nmDataLayerInfos = {"editor_group":"Groupe Nice-Matin","environnement":"nicematin","title_article":"","keywords":[],"topics":[],"publication_date":"","media_enrichment":[],"blocked_article":"","premium_article":"","length_word":"","nb_paragraph":"","reading_time":"","sponsored":"","sponsored_by":"","INSEE_code":"","zipcode":"","departement_id":"","departement_label":"","region":"","city":"","editor_user_id":"","email_hashed":"","inscription_date":"","user_connected":false,"user_subscriber":false,"type_subscription":[]}
# const nmDataLayer = {...nmDataLayerInfos, ...nmDataLayerNavigation}
# dataLayer.push(nmDataLayer);
# dataLayer.push({"nm_data_layer": nmDataLayer});
#        </script>
#       </meta>
#      </meta>
#     </meta>
#    </link>
#   </link>
#  </head>
#  <body class="homepage">
#   <!-- script Gravity -->
#   <script type="text/javascript">
#    // -------- BEGIN TAG ALLIANCE GRAVITY --------
# var grvt_customProperties = {};
# var grvt_siteToken = 'nice_matin21';
# var grvt_processingToken = 'five-arizona';
# var script = document.createElement('script');
# script.src = "https://tag.agrvt.com/tag/v2/wrapper.js";
# document.head.appendChild(script);
# // -------- END TAG ALLIANCE GRAVITY --------
#   </script>
#   <!-- end script Gravity -->
#   <div id="menu-header-wrapper">
#    <header class="nm" data-has-ribbon-bottom="" id="menu-header">
#     <nav class="ribbon-top">
#      <ul class="left">
#       <li class="burger-menu">
#        <span class="item item-big" id="burger-menu-button-toggler">
#         <i class="icon-burger">
#         </i>
#        </span>
#       </li>
#       <li class="hide-down-md hide-up-xl">
#        <a class="item item-hover item-journal header-link" href="/newspapers">
#         <img alt="Journal du jour" src="https://fyooyzbm.filerobot.com/v7/https://static01.nicematin.com/media/staticjel/xlarge/nicematin/nice/2024-06-11.jpg?w=70&amp;h=50&amp;gravity=north"/>
#         <p>
#          Lire le
#          <br/>
#          journal
#         </p>
#        </a>
#       </li>
#       <li class="hide-down-xl">
#        <a class="item item-big search header-link" href="https://www.nicematin.com/recherche">
#         <i class="icon-search">
#         </i>
#        </a>
#       </li>
#       <li class="hide-down-xl">
#        <i class="separator">
#        </i>
#       </li>
#       <li class="hide-down-xl">
#        <a class="item item-hover item-journal header-link" href="/newspapers">
#         <img alt="Journal du jour" src="https://fyooyzbm.filerobot.com/v7/https://static01.nicematin.com/media/staticjel/xlarge/nicematin/nice/2024-06-11.jpg?w=70&amp;h=50&amp;gravity=north"/>
#         <p>
#          Lire le
#          <br/>
#          journal
#         </p>
#        </a>
#       </li>
#      </ul>
#      <ul class="middle">
#       <li>
#        <a class="item logo" href="https://www.nicematin.com/">
#         <img alt="Nice-Matin" src="https://cdn.assets01.nicematin.com/build/imgs/titles/title_nm.f937a794.png"/>
#        </a>
#       </li>
#      </ul>
#      <ul class="right">
#       <li class="hide-down-lg">
#        <a class="item item-hover header-link" href="https://www.nicematin.com/user/login?_redirect_target_path=https://www.nicematin.com/" rel="nofollow">
#         <i class="icon-user">
#         </i>
#         <p>
#          Se connecter
#         </p>
#        </a>
#       </li>
#       <li>
#        <a class="button yellow header-link" data-label="Abonnez-vous" href="https://abo.nicematin.com/abonnement/formules?lastpage_abo=https://www.nicematin.com/&amp;lastclic_abo=Abonnez-vous&amp;lastclic_1er_niveau_abo=https://abo.nicematin.com/abonnement/formules&amp;lastclic_2e_niveau_abo=header-abo-link">
#         Abonnez-vous
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <nav class="ribbon-bottom" id="menu-header-ribbon-bottom">
#      <ul>
#       <li class="header-link-container">
#        <a class="header-link-primary" href="https://www.nicematin.com/sujet/elections-legislatives">
#         Elections législatives
#        </a>
#       </li>
#       <li class="dropdown header-link-container">
#        <span class="heading-title">
#         Actualités
#        </span>
#        <div class="submenu">
#         <div class="submenu-content content">
#          <div class="content-row">
#           <div>
#            <h4 class="header-sublink">
#             Actualités
#            </h4>
#            <ul class="content-list">
#             <li class="">
#              <a class="header-link-secondary" href="https://www.nicematin.com/sujet/faits-de-societe">
#               Société
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" href="https://www.nicematin.com/sujet/faits-divers">
#               Faits divers
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" href="https://www.nicematin.com/sujet/economie">
#               Économie
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" href="https://www.nicematin.com/sujet/politique">
#               Politique
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" href="https://www.nicematin.com/sujet/sport">
#               Sports
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" href="https://www.nicematin.com/sujet/sante">
#               Santé
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" href="https://www.nicematin.com/sujet/ogcnice">
#               OGC Nice
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" href="https://www.nicematin.com/sujet/opinion">
#               Opinion
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" href="https://www.nicematin.com/sujet/culture">
#               Culture
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" href="https://www.nicematin.com/sujet/jeux-olympiques">
#               Jeux Olympiques
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="article-preview">
#            <a class="rearrange header-article-preview" data-target="Actualités_article_preview_image1" href="https://www.nicematin.com/faits-divers/feu-de-vidauban-trois-hameaux-en-cours-d-evacuation-au-plan-de-la-tour-926972">
#             <figure>
#              <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="protec/DATA_ART_13607207-ll1hHzBs.jpg?vh=bfe599&amp;ci_seal=9ae4ebaf66" operation="crop"/>
#             </figure>
#             <div class="block-title">
#              <div class="thematic-container">
#               <div class="classification">
#                <a class="thematic" href="/sujet/faits-divers" target="_blank">
#                 Faits divers
#                </a>
#               </div>
#              </div>
#              <a class="article-title" data-target="Actualités_article_preview_title1" href="https://www.nicematin.com/faits-divers/feu-de-vidauban-trois-hameaux-en-cours-d-evacuation-au-plan-de-la-tour-926972">
#               <h3>
#                Feu dans le massif des Maures: trois hameaux en cours d’évacuation au Plan-de-la-Tour
#               </h3>
#              </a>
#             </div>
#            </a>
#           </div>
#           <div class="article-preview">
#            <a class="rearrange header-article-preview" data-target="Actualités_article_preview_image2" href="https://www.nicematin.com/faits-divers/600-hectares-de-foret-parcourus-des-dizaines-devacuations-on-fait-le-point-sur-lincendie-en-cours-dans-le-massif-des-maures-926963">
#             <figure>
#              <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="IMG-20240611-WA0021-5mPUgOmz.jpg?vh=228190&amp;ci_seal=5d5c2bffac" operation="crop"/>
#             </figure>
#             <div class="block-title">
#              <div class="thematic-container">
#               <div class="classification">
#                <a class="thematic" href="/sujet/faits-divers" target="_blank">
#                 Faits divers
#                </a>
#               </div>
#              </div>
#              <a class="article-title" data-target="Actualités_article_preview_title2" href="https://www.nicematin.com/faits-divers/600-hectares-de-foret-parcourus-des-dizaines-devacuations-on-fait-le-point-sur-lincendie-en-cours-dans-le-massif-des-maures-926963">
#               <h3>
#                600 hectares de forêt parcourus, des dizaines d'évacuations... On fait le point sur l'incendie en cours dans le massif des Maures
#               </h3>
#              </a>
#             </div>
#            </a>
#           </div>
#           <div class="article-preview">
#            <a class="rearrange header-article-preview" data-target="Actualités_article_preview_image3" href="https://www.nicematin.com/faits-de-societe/que-pensent-les-nicois-de-l-alliance-proposee-par-eric-ciotti-au-rn--926966">
#             <figure>
#              <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="protec/DATA_ART_13605978-DiT83VLT.jpg?vh=77c5c0&amp;ci_seal=1b2c3cf55d" operation="crop"/>
#             </figure>
#             <div class="block-title">
#              <div class="thematic-container">
#               <i class="icon-lock">
#               </i>
#               <div class="classification">
#                <a class="thematic" href="/sujet/faits-de-societe" target="_blank">
#                 Faits de société
#                </a>
#               </div>
#              </div>
#              <a class="article-title" data-target="Actualités_article_preview_title3" href="https://www.nicematin.com/faits-de-societe/que-pensent-les-nicois-de-l-alliance-proposee-par-eric-ciotti-au-rn--926966">
#               <h3>
#                Que pensent les Niçois de l’alliance proposée par Eric Ciotti au RN? On est allé leur demander
#               </h3>
#              </a>
#             </div>
#            </a>
#           </div>
#           <div class="article-preview">
#            <a class="rearrange header-article-preview" data-target="Actualités_article_preview_image4" href="https://www.nicematin.com/politique/est-il-possible-de-voter-aux-elections-legislatives-si-on-a-18-ans-avant-le-30-juin-ou-entre-les-deux-tours-926948">
#             <figure>
#              <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="maxmatinarch509593-K6zwqDBg.jpg?vh=9f4d4e&amp;ci_seal=b948232ed3" operation="crop"/>
#             </figure>
#             <div class="block-title">
#              <div class="thematic-container">
#               <div class="classification">
#                <a class="thematic" href="/sujet/politique" target="_blank">
#                 Politique
#                </a>
#               </div>
#              </div>
#              <a class="article-title" data-target="Actualités_article_preview_title4" href="https://www.nicematin.com/politique/est-il-possible-de-voter-aux-elections-legislatives-si-on-a-18-ans-avant-le-30-juin-ou-entre-les-deux-tours-926948">
#               <h3>
#                Est-il possible de voter aux élections législatives si on a 18 ans avant le 30 juin ou entre les deux tours?
#               </h3>
#              </a>
#             </div>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </li>
#       <li class="header-link-container">
#        <a class="header-link-primary" href="https://www.nicematin.com/sujet/video">
#         Vidéos
#        </a>
#       </li>
#       <li class="header-link-container">
#        <a class="header-link-primary" href="https://www.nicematin.com/sujet/faits-divers">
#         Faits-divers
#        </a>
#       </li>
#       <li class="header-link-container">
#        <a class="header-link-primary" href="https://www.nicematin.com/sujet/diane-emploi">
#         Emploi
#        </a>
#       </li>
#       <li class="dropdown header-link-container">
#        <span class="heading-title">
#         Ma ville
#        </span>
#        <div class="submenu">
#         <div class="submenu-content content">
#          <div class="content-row">
#           <div>
#            <h4 class="header-sublink">
#             Ma ville
#            </h4>
#            <ul class="content-list">
#             <li class="">
#              <a class="header-link-secondary" data-label="Nice" href="https://www.nicematin.com/ville/nice">
#               Nice
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" data-label="Saint-Laurent-du-Var" href="https://www.nicematin.com/commune/saint-laurent-du-var">
#               Saint-Laurent-du-Var
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" data-label="Cagnes-sur-Mer" href="https://www.nicematin.com/ville/cagnes">
#               Cagnes-sur-Mer
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" data-label="Cannes" href="https://www.nicematin.com/ville/cannes">
#               Cannes
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" data-label="Antibes" href="https://www.nicematin.com/ville/antibes">
#               Antibes
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" data-label="Grasse" href="https://www.nicematin.com/ville/grasse">
#               Grasse
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" data-label="Menton" href="https://www.nicematin.com/ville/menton">
#               Menton
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" data-label="Monaco" href="https://www.nicematin.com/ville/monaco">
#               Monaco
#              </a>
#             </li>
#             <li class="">
#              <a class="header-link-secondary" data-label="Vallées" href="https://www.nicematin.com/ville/vallees">
#               Vallées
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="article-preview">
#            <a class="rearrange header-article-preview" data-target="Ma ville_article_preview_image1" href="https://www.nicematin.com/faits-divers/feu-de-vidauban-trois-hameaux-en-cours-d-evacuation-au-plan-de-la-tour-926972">
#             <figure>
#              <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="protec/DATA_ART_13607207-ll1hHzBs.jpg?vh=bfe599&amp;ci_seal=9ae4ebaf66" operation="crop"/>
#             </figure>
#             <div class="block-title">
#              <div class="thematic-container">
#               <div class="classification">
#                <a class="thematic" href="/sujet/faits-divers" target="_blank">
#                 Faits divers
#                </a>
#               </div>
#              </div>
#              <a class="article-title" data-target="Ma ville_article_preview_title1" href="https://www.nicematin.com/faits-divers/feu-de-vidauban-trois-hameaux-en-cours-d-evacuation-au-plan-de-la-tour-926972">
#               <h3>
#                Feu dans le massif des Maures: trois hameaux en cours d’évacuation au Plan-de-la-Tour
#               </h3>
#              </a>
#             </div>
#            </a>
#           </div>
#           <div class="article-preview">
#            <a class="rearrange header-article-preview" data-target="Ma ville_article_preview_image2" href="https://www.nicematin.com/faits-divers/600-hectares-de-foret-parcourus-des-dizaines-devacuations-on-fait-le-point-sur-lincendie-en-cours-dans-le-massif-des-maures-926963">
#             <figure>
#              <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="IMG-20240611-WA0021-5mPUgOmz.jpg?vh=228190&amp;ci_seal=5d5c2bffac" operation="crop"/>
#             </figure>
#             <div class="block-title">
#              <div class="thematic-container">
#               <div class="classification">
#                <a class="thematic" href="/sujet/faits-divers" target="_blank">
#                 Faits divers
#                </a>
#               </div>
#              </div>
#              <a class="article-title" data-target="Ma ville_article_preview_title2" href="https://www.nicematin.com/faits-divers/600-hectares-de-foret-parcourus-des-dizaines-devacuations-on-fait-le-point-sur-lincendie-en-cours-dans-le-massif-des-maures-926963">
#               <h3>
#                600 hectares de forêt parcourus, des dizaines d'évacuations... On fait le point sur l'incendie en cours dans le massif des Maures
#               </h3>
#              </a>
#             </div>
#            </a>
#           </div>
#           <div class="article-preview">
#            <a class="rearrange header-article-preview" data-target="Ma ville_article_preview_image3" href="https://www.nicematin.com/faits-de-societe/que-pensent-les-nicois-de-l-alliance-proposee-par-eric-ciotti-au-rn--926966">
#             <figure>
#              <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="protec/DATA_ART_13605978-DiT83VLT.jpg?vh=77c5c0&amp;ci_seal=1b2c3cf55d" operation="crop"/>
#             </figure>
#             <div class="block-title">
#              <div class="thematic-container">
#               <i class="icon-lock">
#               </i>
#               <div class="classification">
#                <a class="thematic" href="/sujet/faits-de-societe" target="_blank">
#                 Faits de société
#                </a>
#               </div>
#              </div>
#              <a class="article-title" data-target="Ma ville_article_preview_title3" href="https://www.nicematin.com/faits-de-societe/que-pensent-les-nicois-de-l-alliance-proposee-par-eric-ciotti-au-rn--926966">
#               <h3>
#                Que pensent les Niçois de l’alliance proposée par Eric Ciotti au RN? On est allé leur demander
#               </h3>
#              </a>
#             </div>
#            </a>
#           </div>
#           <div class="article-preview">
#            <a class="rearrange header-article-preview" data-target="Ma ville_article_preview_image4" href="https://www.nicematin.com/politique/est-il-possible-de-voter-aux-elections-legislatives-si-on-a-18-ans-avant-le-30-juin-ou-entre-les-deux-tours-926948">
#             <figure>
#              <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="maxmatinarch509593-K6zwqDBg.jpg?vh=9f4d4e&amp;ci_seal=b948232ed3" operation="crop"/>
#             </figure>
#             <div class="block-title">
#              <div class="thematic-container">
#               <div class="classification">
#                <a class="thematic" href="/sujet/politique" target="_blank">
#                 Politique
#                </a>
#               </div>
#              </div>
#              <a class="article-title" data-target="Ma ville_article_preview_title4" href="https://www.nicematin.com/politique/est-il-possible-de-voter-aux-elections-legislatives-si-on-a-18-ans-avant-le-30-juin-ou-entre-les-deux-tours-926948">
#               <h3>
#                Est-il possible de voter aux élections législatives si on a 18 ans avant le 30 juin ou entre les deux tours?
#               </h3>
#              </a>
#             </div>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </li>
#       <li class="dropdown header-link-container">
#        <span class="heading-title">
#         Services
#        </span>
#        <div class="submenu">
#         <div class="submenu-content content">
#          <div class="content-row">
#           <div class="services-container">
#            <ul class="submenu-col">
#             <li>
#              <h4 class="header-sublink">
#               Annonces
#              </h4>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Avis de décès" href="/carnet-avis-deces?dpt=06&amp;commune=Toutes+les+communes">
#               Avis de décès
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Annonces légales" href="/annonces/annonces-legales/">
#               Annonces légales
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Marchés publics" href="https://www.francemarches.com/nice-matin">
#               Marchés publics
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Emploi" href="/sujet/diane-emploi">
#               Emploi
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Déposer une petite annonce" href="/petites-annonces">
#               Déposer une petite annonce
#              </a>
#             </li>
#            </ul>
#            <ul class="submenu-col">
#             <li>
#              <h4 class="header-sublink">
#               Nos services
#              </h4>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Newsletters" href="/newsletters">
#               Newsletters
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Programme TV" href="https://www.diverto.tv/programme-tv" target="_blank">
#               Programme TV
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Météo" href="/sujet/meteo">
#               Météo
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Vos déclarations" href="/saintvalentin">
#               Vos déclarations
#              </a>
#             </li>
#            </ul>
#            <ul class="submenu-col">
#             <li>
#              <h4 class="header-sublink">
#               Nos partenaires
#              </h4>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Côte d'Azur Éco" href="/sujet/cotedazur-eco">
#               Côte d'Azur Éco
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Côte d'Azur Santé" href="/sujet/cotedazur-sante">
#               Côte d'Azur Santé
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Nos Ambassadeurs" href="/sujet/nos-ambassadeurs">
#               Nos Ambassadeurs
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Région Sud" href="/sujet/le-soleil-se-leve-au-sud">
#               Région Sud
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Métropole Nice Côte d’Azur" href="/sujet/metropole-nice-cote-d-azur">
#               Métropole Nice Côte d’Azur
#              </a>
#             </li>
#            </ul>
#            <ul class="submenu-col">
#             <li>
#              <h4 class="header-sublink">
#               Nos suppléments
#              </h4>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Guide des Vins" href="/sujet/guide-des-vins">
#               Guide des Vins
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Guide Été" href="/sujet/guide-ete">
#               Guide Été
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Nouvelle Ère" href="/sujet/nouvelle-ere">
#               Nouvelle Ère
#              </a>
#             </li>
#            </ul>
#            <ul class="submenu-col">
#             <li>
#              <h4 class="header-sublink">
#               Nos évènements
#              </h4>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Tour des Alpes-Maritimes" href="/cyclisme/tour-des-alpes-maritimes">
#               Tour des Alpes-Maritimes
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Classic Var" href="/cyclisme/classic-var">
#               Classic Var
#              </a>
#             </li>
#             <li>
#              <a class="header-link-secondary" data-label="Golf" href="/sujet/golf">
#               Golf
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#       </li>
#       <li class="header-link-container">
#        <a class="header-link current-topic" href="https://www.nicematin.com/sujet/jeux-olympiques">
#         JO 2024
#        </a>
#       </li>
#      </ul>
#     </nav>
#    </header>
#   </div>
#   <div id="menu-burger-wrapper">
#    <nav class="menu-burger">
#     <ul class="menu-burger-icons">
#      <li>
#       <a class="menu-burger-close item-big" href="#">
#        <i class="icon-close">
#        </i>
#       </a>
#      </li>
#     </ul>
#     <ul class="menu-burger-research">
#      <form action="https://www.nicematin.com/recherche" class="search-container">
#       <i class="icon-search">
#       </i>
#       <input id="nm_search_input" name="search" placeholder="Recherche" type="text"/>
#      </form>
#     </ul>
#     <ul class="menu-burger-newspaper">
#      <li>
#       <a href="/newspapers">
#        <img alt="Journal du jour" src="https://fyooyzbm.filerobot.com/v7/https://static01.nicematin.com/media/staticjel/xlarge/nicematin/nice/2024-06-11.jpg?w=115&amp;h=80&amp;gravity=north"/>
#       </a>
#      </li>
#      <li class="menu-burger-newspaper-date">
#       <span>
#        Mardi 11 juin
#       </span>
#       <a class="menu-burger-newspaper-button" href="/newspapers">
#        Lire le journal
#       </a>
#      </li>
#     </ul>
#     <ul class="menu-burger-links">
#      <li class="hide-down-md">
#       <a class="icon-user burger-link" href="https://www.nicematin.com/user/login?_redirect_target_path=https://www.nicematin.com/user/profil">
#        Se connecter
#       </a>
#      </li>
#      <li>
#       <a class="solution burger-link" href="/folders">
#        Dossiers Solutions
#       </a>
#      </li>
#      <li>
#       <a class="tv burger-link" href="https://www.diverto.tv/programme-tv" target="_blank">
#        Programme TV
#       </a>
#      </li>
#      <li class="hide-down-md">
#       <a class="podcast burger-link" href="https://www.nicematin.com/podcasts/">
#        Podcast
#       </a>
#      </li>
#      <li class="hide-down-md">
#       <a class="videos2 burger-link" href="https://www.nicematin.com/sujet/video">
#        Vidéos
#       </a>
#      </li>
#      <li>
#       <a class="newsletters burger-link" href="/newsletters">
#        Newsletters
#       </a>
#      </li>
#      <li class="highlight">
#       <a class="live burger-link" href="/sujet/jeux-olympiques">
#        JO2024
#       </a>
#      </li>
#     </ul>
#     <ul class="menu-burger-submenu">
#      <li class="menu-burger-submenu--first_level">
#       <strong data-content="headings" data-level="level-first">
#        Actualités
#       </strong>
#       <ul>
#        <li class="menu-burger-submenu--second_level">
#         <a class="burger-link" data-label="
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="menu-burger-submenu--first_level">
#       <strong data-content="legal-ads" data-level="level-first">
#        Services
#       </strong>
#       <ul>
#        <li class="menu-burger-submenu--second_level">
#         <strong data-content="annonces" data-level="level-second">
#          Annonces
#         </strong>
#         <ul class="annonces-links">
#          <li class="menu-burger-submenu--third_level">
#           <a class="burger-link" data-label="Avis de décès" data-level="level-third" href="/carnet-avis-deces?dpt=06&amp;commune=Toutes+les+communes">
#            Avis de décès
#           </a>
#          </li>
#          <li class="menu-burger-submenu--third_level">
#           <strong data-content="annonces_legales" data-level="level-third">
#            Annonces légales
#           </strong>
#           <ul class="legalplus-links">
#            <li class="menu-burger-submenu--fourth_level">
#             <a class="burger-link" data-content="annonces_legales" data-label="legalplus-read-nm" data-level="level-fourth" href="/annonces/annonces-legales/">
#              Consulter les annonces légales publiées sur nicematin.com
#             </a>
#            </li>
#            <li class="menu-burger-submenu--fourth_level">
#             <a class="burger-link" data-content="annonces_legales" data-label="legalplus-create-individuals" data-level="level-fourth" href="https://legales-nicematin.fr/">
#              Publier une annonce légale
#              <span>
#               Sociétés et particuliers
#              </span>
#             </a>
#            </li>
#            <li class="menu-burger-submenu--fourth_level">
# ...
#         Annonces légales
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://www.francemarches.com/recherche?supports%5B0%5D=51&amp;supports%5B1%5D=53&amp;types%5B%5D=171&amp;etat=en-cours" target="_blank">
#         Marchés publics
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://www.nicematin.com/sujet/diane-emploi">
#         Emploi
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://www.nicematin.com/petites-annonces">
#         Déposer une petite annonce
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div>
#      <div class="footer-title">
#       <span>
#        Groupe Nice-Matin
#       </span>
#      </div>
#      <ul class="links">
#       <li>
#        <a class="footer-link" href="https://w2mo3p6qqd6.typeform.com/to/br8xqQbV" target="_blank">
#         Votre publicité sur Nice-Matin
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://groupenicematin.zendesk.com/hc/fr/requests/new" target="_blank">
#         Contactez Nice-Matin
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://groupenicematin.zendesk.com/hc/fr" target="_blank">
#         FAQ
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://www.nicematin.com/cgu">
#         Conditions générales d'utilisation
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://www.nicematin.com/cgv">
#         Conditions générales de vente
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://www.nicematin.com/index-de-egalite-professionnelle-au-sein-du-groupe-nice-matin">
#         Index de l'égalite professionnelle
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://www.nicematin.com/politique-de-confidentialite">
#         Politique de confidentialité et cookies
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://www.nicematin.com/mentions-legales">
#         Mentions légales
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://www.nicematin.com/plandusite">
#         Plan du site
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://fyooyzbm.filerobot.com/v7/data-storage/static-docs/bilan-carbone_2022-OR9LLO1X.pdf?vh=33264a&amp;func=proxy&amp;ci_seal=abd531a52d" target="_blank">
#         Bilan carbone du groupe
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div>
#      <div class="footer-title">
#       <span>
#        Abonnement
#       </span>
#      </div>
#      <ul class="links">
#       <li>
#        <a class="footer-link" href="https://abo.nicematin.com/abonnement/formules?lastpage_abo=https://www.nicematin.com/&amp;lastclic_abo=S%27abonner%20%C3%A0%20Nice-Matin&amp;lastclic_1er_niveau_abo=https://abo.nicematin.com/abonnement/formules&amp;lastclic_2e_niveau_abo=footer-abo-link">
#         S'abonner à Nice-Matin
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://www.nicematin.com/user/login?_redirect_target_path=https://www.nicematin.com/user/cancel/subscription">
#         Résilier mon abonnement
#        </a>
#       </li>
#       <!--<li><a href="">Nos newsletter</a></li>
#                 <li><a href="">Nos applications</a></li>-->
#      </ul>
#     </div>
#     <div>
#      <div class="footer-title">
#       <span>
#        Suivez Nice-Matin sur les réseaux sociaux
#       </span>
#      </div>
#      <ul class="social">
#       <li>
#        <a class="footer-link" href="https://www.linkedin.com/company/groupenicematin/" target="_blank">
#         <i class="icon-linkedin">
#         </i>
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://twitter.com/Nice_Matin" target="_blank">
#         <i class="icon-twitter">
#         </i>
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://www.facebook.com/Page.NiceMatin/" target="_blank">
#         <i class="icon-facebook">
#         </i>
#        </a>
#       </li>
#       <li>
#        <a class="footer-link" href="https://www.instagram.com/nice_matin" target="_blank">
#         <i class="icon-instagram">
#         </i>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <img alt="0" border="0" height="1" src="https://api.optinproject.com/rt/visit/nicematin.gif" width="1">
#    </img>
#   </footer>
#   <script>
#    var NMConfig = {
#         channel: "nicematin",
#         acronym: "nm",
#         default_img: "nicematin/default.png",
#         path: {"subscription":"https:\/\/www.nicematin.com\/abonnement\/offre\/1055","base_url":{"main":"https:\/\/www.nicematin.com","freemium":"https:\/\/www.nicematin.com","filerobot_cdn":"https:\/\/fyooyzbm.filerobot.com\/v7\/","filerobot_store":"https:\/\/fyooyzbm.airstore.io\/"},"img":["https:\/\/static01.nicematin.com\/media\/npo\/","https:\/\/static02.nicematin.com\/media\/npo\/","https:\/\/static03.nicematin.com\/media\/npo\/","https:\/\/static04.nicematin.com\/media\/npo\/","https:\/\/static05.nicematin.com\/media\/npo\/"],"jel":["https:\/\/static01.nicematin.com\/media\/staticjel\/","https:\/\/static02.nicematin.com\/media\/staticjel\/","https:\/\/static03.nicematin.com\/media\/staticjel\/","https:\/\/static03.nicematin.com\/media\/staticjel\/","https:\/\/static03.nicematin.com\/media\/staticjel\/"],"assets":["https:\/\/cdn.assets01.nicematin.com\/assets\/","https:\/\/cdn.assets02.nicematin.com\/assets\/","https:\/\/cdn.assets03.nicematin.com\/assets\/","https:\/\/cdn.assets04.nicematin.com\/assets\/","https:\/\/cdn.assets05.nicematin.com\/assets\/"],"static":["https:\/\/cdn.static01.nicematin.com\/media\/static\/","https:\/\/cdn.static02.nicematin.com\/media\/static\/","https:\/\/cdn.static03.nicematin.com\/media\/static\/","https:\/\/cdn.static04.nicematin.com\/media\/static\/","https:\/\/cdn.static05.nicematin.com\/media\/static\/"],"offers":["https:\/\/cdn.static01.nicematin.com\/media\/offers\/","https:\/\/cdn.static02.nicematin.com\/media\/offers\/","https:\/\/cdn.static03.nicematin.com\/media\/offers\/","https:\/\/cdn.static04.nicematin.com\/media\/offers\/","https:\/\/cdn.static05.nicematin.com\/media\/offers\/"]},
#                 };
#             var NMAuth = {user: {"userId":0,"isConnected":false,"userEmail":""} };
#       var NMFileRobotConfig = {"enabled":false,"enabledReact":false,"token":"fyooyzbm","domain":"filerobot.com","baseUrl":"https:\/\/store.filerobot.com\/fyooyzbm\/","cdnUrl":"https:\/\/fyooyzbm.filerobot.com\/v7\/","lazyLoading":true,"presets":{"xs":"(max-width: 480px)","sm":"(min-width: 481px)","md":"(min-width: 721px)","lg":"(min-width: 961px)","xl":"(min-width: 1201px)","xw":"(min-width: 1501px)"}};
#       var NMBaseURL = 'https://www.nicematin.com';
#             var pubstackVersion = "43a11954-7d85-4b9f-879a-26e361e03ffa";
#   </script>
#   <script src="https://cdn.assets03.nicematin.com/build/1757.13915057.js">
#   </script>
#   <script src="https://cdn.assets02.nicematin.com/build/8422.724a5319.js">
#   </script>
#   <script src="https://cdn.assets01.nicematin.com/build/5775.e1c31318.js">
#   </script>
#   <script src="https://cdn.assets03.nicematin.com/build/3249.c4d5436a.js">
#   </script>
#   <script src="https://cdn.assets02.nicematin.com/build/3946.c2f64eb2.js">
#   </script>
#   <script src="https://cdn.assets01.nicematin.com/build/js/freemium/app.9db47e47.js">
#   </script>
#   <script src="https://cdn.assets01.nicematin.com/build/js/freemium/menu.49608d99.js">
#   </script>
#   <script type="text/javascript">
#    window.NMArticleConfig = {
#         'outbrain': 'fac083a3',
#         'isNative': 'false',
#         'isMobile': /Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i.test(navigator.userAgent),
#         'userIsConnected': "false",
#         'userIsSubscriber': "false",
#       };
#   </script>
#   <script type="text/javascript">
#    (function() {
#
#                 /** CONFIGURATION END **/
#                 function loadChartbeat() {
#                     var e = document.createElement('script');
#                     var n = document.getElementsByTagName('script')[0];
#                     e.type = 'text/javascript';
#                     e.async = true;
#                     e.src = '//static.chartbeat.com/js/chartbeat.js';
#                     n.parentNode.insertBefore(e, n);
#                 }
#
#                 window.didomiOnReady = window.didomiOnReady || [];
#                 window.didomiOnReady.push(function (Didomi) {
#
#                     /** CONFIGURATION START **/
#                     var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});
#                                         var cbConsent = Didomi.getUserConsentStatus(Didomi.Purposes.Cookies, 'c:chartbeat');
#
#                     var _cbq = window._cbq = (window._cbq || []);
#
#                     if (cbConsent) {
#                         _sf_async_config.noCookies = !cbConsent;
#                         loadChartbeat();
#                     }
#
#                     Didomi.on('notice.clickagree', function() {
#                         _sf_async_config.noCookies = false;
#                         loadChartbeat();
#                     });
#
#                     Didomi.on('preferences.clickagreetoall', function() {
#                         _sf_async_config.noCookies = false;
#                         loadChartbeat();
#                     });
#
#                 });
#
#             })();
#   </script>
#   <script type="text/javascript">
#    var timenjoyWidget = insertTimenjoyWidget(
#               "Smart-Event-NMMM",
#               "_l002zhGiqVwWU3NKhvHo"
#             );
#
#     var screenWidth = document.documentElement.clientWidth || window.innerWidth || document.body.clientWidth;
#     var lockResize = false;
#
#             if (screenWidth <= 480) {
#             var timenjoyContainer = document.querySelector(".timEnjoyFrame--slider.mobile");
#         } else {
#             var timenjoyContainer = document.querySelector(".timEnjoyFrame--slider.desk");
#         }
#
#     window.addEventListener("resize", () => {
#         if (lockResize) {
#             return;
#         }
#
#         screenWidth = document.documentElement.clientWidth || window.innerWidth || document.body.clientWidth;
#         let timeMobile = document.querySelector('.timEnjoyFrame--slider.mobile');
#         let timeDesk = document.querySelector('.timEnjoyFrame--slider.desk');
#
#                     if (timeDesk.querySelector('iframe') !== null && timeMobile.querySelector('iframe') === null && screenWidth <= 480) {
#                 lockResize = true;
#                 timeDesk.querySelector('iframe').remove()
#                 timeMobile.appendChild(iframeT);
#             } else if (timeMobile.querySelector('iframe') !== null && timeDesk.querySelector('iframe') === null && screenWidth > 480) {
#                 lockResize = true;
#                 timeMobile.querySelector('iframe').remove()
#                 timeDesk.appendChild(iframeT);
#             }
#
#
#         setTimeout(function () {
#             lockResize = false;
#         }, 1000);
#     });
#
#     if (typeof iframeT !== "undefined") {
#       timenjoyContainer.appendChild(iframeT);
#     }
#
#     if (typeof timenjoyWidget !== "undefined") {
#       timenjoyContainer.appendChild(timenjoyWidget);
#       timenjoyContainer.appendChild(insertTimenjoyScript());
#     }
#
#     function insertTimenjoyIframe(src, height, style) {
#         let iframeT = document.createElement("iframe");
#         iframeT.src = src;
#         iframeT.height = height;
#         iframeT.style = style;
#
#         return iframeT;
#     }
#
#     function insertTimenjoyWidget(selection, appSecret) {
#       let widget = document.createElement("tnj-widget");
#       widget.dataset.selection = selection;
#       widget.dataset.app_secret = appSecret;
#
#       return widget;
#     }
#
#     function insertTimenjoyScript() {
#       let script = document.createElement("script");
#       script.src = 'https://widget.timenjoy.fr/main.js';
#       script.async = true;
#
#       return script;
#     }
#   </script>
#   <div class="nm-cookies-wall nm-cookies-wall--section nm" id="nm-cookies-wall">
#    <div class="nm-cookies-wall--grid">
#     <div class="nm-cookies-wall--header">
#      <img alt="Nice-Matin" class="nm-cookies-wall--logo_editeur" src="https://cdn.assets03.nicematin.com/build/imgs/titles/title_nm.8d47c419.svg">
#       <div class="nm-cookies-wall--header--sub">
#        <p class="nm-cookies-wall--title" id="nm-cookies-wall--title">
#         Un cookie pour nous soutenir
#        </p>
#        <div class="hide-down-md" id="nm-cookies-wall--btn">
#         <a class="nm-cookies-wall--btn--accept nm" href="#" id="nm-cookies-wall--btn--accept" onclick="Didomi.setUserAgreeToAll();" title="J'accepte les cookies">
#          J'accepte les cookies
#         </a>
#        </div>
#       </div>
#      </img>
#     </div>
#     <div class="nm-cookies-wall--message" id="nm-cookies-wall--message">
#      <p>
#       Nous avons besoin de vos cookies pour vous offrir une expérience de lecture optimale et vous proposer des publicités personnalisées.
#      </p>
#      <p>
#       Accepter les cookies, c’est permettre grâce aux revenus complémentaires de soutenir le travail de nos 180 journalistes qui veillent au quotidien à vous offrir une information de qualité et diversifiée. Ainsi, vous pourrez accéder librement au site.
#      </p>
#      <p>
#       Vous pouvez choisir de refuser les cookies en vous connectant ou en vous abonnant.
#      </p>
#      <div class="nm-cookies-wall--btn--group hide-down-md">
#       <div class="nm-cookies-wall--btn--row">
#        <div id="nm-cookies-wall--btn">
#         <a class="nm-cookies-wall--btn--cta" href="https://abo.nicematin.com/cart/products/add?product_id=1055&amp;_redirect_target_path=https://www.nicematin.com/&amp;lastpage_abo=https://www.nicematin.com/&amp;lastclic_abo=Je%20m%27abonne&amp;lastclic_1er_niveau_abo=https://abo.nicematin.com/abonnement/formules&amp;lastclic_2e_niveau_abo=nm-cookies-wall" id="nm-cookies-wall--btn--cta" title="Je m'abonne">
#          Je m'abonne
#         </a>
#        </div>
#        <div class="hide-up-md" id="nm-cookies-wall--btn">
#         <a class="nm-cookies-wall--btn--accept nm" href="#" id="nm-cookies-wall--btn--accept" onclick="Didomi.setUserAgreeToAll();" title="J'accepte les cookies">
#          J'accepte les cookies
#         </a>
#        </div>
#       </div>
#       <div class="nm-cookies-wall--btn--row">
#        <div id="nm-cookies-wall--btn">
#         <a class="nm-cookies-wall--btn--cta" href="https://www.nicematin.com/user/login?_redirect_target_path=https://www.nicematin.com/" id="nm-cookies-wall--btn--cta" rel="nofollow" title="Je me connecte/je crée un compte">
#          Je me connecte/je crée un compte
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="nm-cookies-wall--footer">
#      <p>
#       Merci de la part de toute notre rédaction 🙏
#      </p>
#     </div>
#     <div class="nm-cookies-wall--btn--group hide-up-md">
#      <div class="nm-cookies-wall--btn--row">
#       <div id="nm-cookies-wall--btn">
#        <a class="nm-cookies-wall--btn--cta" href="https://abo.nicematin.com/cart/products/add?product_id=1055&amp;_redirect_target_path=https://www.nicematin.com/&amp;lastpage_abo=https://www.nicematin.com/&amp;lastclic_abo=Je%20m%27abonne&amp;lastclic_1er_niveau_abo=https://abo.nicematin.com/abonnement/formules&amp;lastclic_2e_niveau_abo=nm-cookies-wall" id="nm-cookies-wall--btn--cta" title="Je m'abonne">
#         Je m'abonne
#        </a>
#       </div>
#       <div class="hide-up-md" id="nm-cookies-wall--btn">
#        <a class="nm-cookies-wall--btn--accept nm" href="#" id="nm-cookies-wall--btn--accept" onclick="Didomi.setUserAgreeToAll();" title="J'accepte les cookies">
#         J'accepte les cookies
#        </a>
#       </div>
#      </div>
#      <div class="nm-cookies-wall--btn--row">
#       <div id="nm-cookies-wall--btn">
#        <a class="nm-cookies-wall--btn--cta" href="https://www.nicematin.com/user/login?_redirect_target_path=https://www.nicematin.com/" id="nm-cookies-wall--btn--cta" rel="nofollow" title="Je me connecte/je crée un compte">
#         Je me connecte/je crée un compte
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
top_soup.html.head.title
# Out:
# <title>Actualités et infos en direct - Nice-Matin</title>

# %% [markdown]
# Напишем функцию для получения списка ссылок на странице

# %%
def get_links_list (page, tag, class_to_find):
    """
    Parameters:
    page: link to an html-page to find the links on;
    tag: <tag> to find;
    class_to_find: <class> to find; 
    
    Returns: list of links
    """
    response = requests.get(page, headers={'User-Agent': UserAgent().chrome})
    html = response.content
    soup = BeautifulSoup(html, 'html.parser')
    obj_list = soup.find_all(tag, attrs = {'class':class_to_find})
    links_list = [obj_item.attrs['href'] for obj_item in obj_list if obj_item.attrs['href'][0:25] == 'https://www.nicematin.com']
    return links_list

# %% [markdown]
# Соберем список тематических ссылок на первой странице Nice matin

# %%
theme_links_list = get_links_list(top_page, 'a', 'header-link-secondary')

# %%
theme_links_list
# Out:
# ['https://www.nicematin.com/sujet/faits-de-societe',
#  'https://www.nicematin.com/sujet/faits-divers',
#  'https://www.nicematin.com/sujet/economie',
#  'https://www.nicematin.com/sujet/politique',
#  'https://www.nicematin.com/sujet/sport',
#  'https://www.nicematin.com/sujet/sante',
#  'https://www.nicematin.com/sujet/ogcnice',
#  'https://www.nicematin.com/sujet/opinion',
#  'https://www.nicematin.com/sujet/culture',
#  'https://www.nicematin.com/sujet/jeux-olympiques',
#  'https://www.nicematin.com/ville/nice',
#  'https://www.nicematin.com/commune/saint-laurent-du-var',
#  'https://www.nicematin.com/ville/cagnes',
#  'https://www.nicematin.com/ville/cannes',
#  'https://www.nicematin.com/ville/antibes',
#  'https://www.nicematin.com/ville/grasse',
#  'https://www.nicematin.com/ville/menton',
#  'https://www.nicematin.com/ville/monaco',
#  'https://www.nicematin.com/ville/vallees']

# %%
theme_links_list[0]
# Out:
# 'https://www.nicematin.com/sujet/faits-de-societe'

# %% [markdown]
# Пройдем по всем тематическим ссылкам и соберем итоговый список ссылок на новостные статьи

# %%
allnews_links_list = []

# %%
for link in tqdm(theme_links_list):
    allnews_links_list = allnews_links_list + get_links_list(link, 'a', 'title-link')
    time.sleep(0.3)
# Out:
# 100%|███████████████████████████████████████████| 19/19 [00:15<00:00,  1.20it/s]

# %%
len(allnews_links_list)
# Out:
# 294

# %%
allnews_links_list
# Out:
# ['https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616',
#  'https://www.nicematin.com/faits-de-societe/-face-a-leur-usage-des-ecrans-les-jeunes-appellent-a-l-aide-une-commission-d-experts-propose-de-limiter-l-usage-du-smartphone-en-fonction-de-l-age-926348',
#  'https://www.nicematin.com/faits-de-societe/face-aux-deserts-medicaux-ce-bus-prodigue-des-soins-dentaires-gratuits-en-milieu-rural-926111',
#  'https://www.nicematin.com/faits-de-societe/giulia-sarkozy-ambassadrice-d-une-marque-varoise-926402',
#  'https://www.nicematin.com/faits-de-societe/au-texas-les-anti-ivg-veulent-aller-plus-loin-et-empecher-les-femmes-daller-avorter-ailleurs-926448',
#  'https://www.nicematin.com/environnement/avec-c-monspotfr-on-fait-du-sport-en-respectant-la-nature-926108',
#  'https://www.nicematin.com/faits-de-societe/-mon-vol-annule-pour-la-3e-fois-un-hyerois-bloque-en-nouvelle-caledonie-raconte-926363',
#  'https://www.nicematin.com/cinema/festival-de-cannes-mediapart-publie-une-nouvelle-enquete-sur-le-management-de-thierry-fremaux-qualifie-de-brutal-926366',
#  'https://www.nicematin.com/faits-de-societe/-ce-vieux-nice-meme-s-il-n-est-plus-comme-avant-je-l-aime-toujours-il-organise-un-pique-nique-pour-conserver-l-ame-d-antan--926355',
#  'https://www.nicematin.com/faits-de-societe/les-eleves-peinent-a-trouver-leur-stage-de-seconde-inquietude-du-cote-des-parents-et-des-etablissements-926334',
#  'https://www.nicematin.com/climat/face-au-changement-climatique-deux-modes-demploi-pour-vegetaliser-les-cours-de-recre-926095',
#  'https://www.nicematin.com/faits-de-societe/mort-de-lastronaute-william-anders-de-la-mission-apollo-8-et-photographe-du-lever-de-terre-926325',
#  'https://www.nicematin.com/education/un-nouveau-college-sera-construit-a-drap-il-s-ajoute-a-trois-autres-etablissements-dont-la-realisation-est-deja-programmee--926182',
#  'https://www.nicematin.com/faits-de-societe/et-si-cette-drole-de-maison-en-forme-de-a-etait-lavenir-de-la-construction-925416',
#  'https://www.nicematin.com/politique/elections-europeennes-le-rn-en-tete-a-monaco-et-dans-son-pourtour-926536',
#  'https://www.nicematin.com/info-trafic/-l-enrobe-fond-pose-en-urgence-apres-la-tempete-aline-le-bitume-de-la-route-de-la-colmiane-va-etre-refait-926378',
#  'https://www.nicematin.com/animaux/une-brebis-devoree-et-deux-autres-blessees-a-saint-etienne-de-tinee-juste-avant-la-fete-de-la-transhumance-926379',
#  'https://www.nicematin.com/climat/face-au-changement-climatique-deux-modes-demploi-pour-vegetaliser-les-cours-de-recre-926095',
#  'https://www.nicematin.com/vie-locale/un-nouveau-rond-point-inaugure-dans-l-arriere-pays-de-nice-son-nom-suscite-la-controverse-926211',
#  'https://www.nicematin.com/economie/tama-60-ans-de-travaux-en-famille-926152',
#  'https://www.nicematin.com/education/400-eleves-un-etablissement-a-taille-humaine-on-sait-ou-sera-construit-le-nouveau-college-de-la-vallee-du-paillon-926101']

# %% [markdown]
# Посмотрим на первую ссылку в списке

# %%
allnews_links_list[0]
# Out:
# 'https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616'

# %% [markdown]
# попробуем получить детальную информацию по новости

# %%
response = requests.get(allnews_links_list[0], headers={'User-Agent': UserAgent().chrome})

# %%
response
# Out:
# <Response [200]>

# %%
html = response.content

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="nm" lang="fr">
# <head>
# <meta charset="utf-8"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="icon" type="image/png"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="57x57">
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="60x60">
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="https://cdn.assets01.nicematin.com/build/favicons/freemium/nm_fav.d9370e02.png" rel="icon" sizes="16x16" type="image/png"/> <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <title>"On le fait par dépit, clairement": la galère des lycéens de seconde à Antibes pour trouver un stage de fin d'année - Nice-Matin</title>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Raleway:ital,wght@0,300;0,400;0,500;0,600;0,700;0,900;1,300;1,400;1,500;1,600;1,700;1,900&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Inter:wght@200;300;400;500;600;700;900&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Sanchez:ital@0;1&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@300;400;500;600;700;900&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Roboto+Condensed:ital,wght@0,300;0,400;0,700;1,300;1,400;1,700&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@300;400;500;700;900&amp;display=swap" rel="stylesheet"/>
# <meta content="index, follow" name="robots"/>
# <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots">
# <script type="text/javascript">
# var dfpVars = {"enabled":true,"debug":false,"test":false,"lazy":false,"version_beta":false,"responsive":true,"network_id":"31755961,49811762","page_type":"article_details","level1":"nicematin","level2":"DYNAMIC","level3":"article","level4":"","level5":""};
# var dfpPositions = [];
# var dfpSizes = [];
# var dfpPageTypes = [];
# var dfpTargeting = {"article_id":"926616","GrNM_rubrique":["education","faits-de-societe"],"GrNM_locale":["antibes"],"GrNM_connected":"no","GrNM_subscriber_digital":"no","GrNM_subscriber_print":"no"};
# </script>
# <script type="text/javascript">
# var smartAdServerConf = {"network_id":3944,"site_id":430463,"page_id":{"desktop":1412271,"mobile":1412274},"formats":{"desktop":[{"id":97818,"tagId":"div-ps-ad-banniere_haute"},{"id":97819,"tagId":"div-ps-ad-banniere_basse"},{"id":97817,"tagId":"div-ps-ad-pave_bas"},{"id":97815,"tagId":"div-ps-ad-pave_haut"},{"id":118370,"tagId":"div-ps-ad-pave_article0"},{"id":97825,"tagId":"div-ps-ad-pave_article"},{"id":103885,"tagId":"div-ps-ad-pave_article2"},{"id":103886,"tagId":"div-ps-ad-pave_article3"},{"id":119437,"tagId":"div-ps-ad-pave_article4"},{"id":119438,"tagId":"div-ps-ad-pave_article5"},{"id":119439,"tagId":"div-ps-ad-pave_article6"},{"id":103883,"tagId":"div-ps-ad-rectangle169eme"}],"mobile":[{"id":97819,"tagId":"div-ps-ad-banniere_basse"},{"id":97818,"tagId":"div-ps-ad-banniere_haute"},{"id":97817,"tagId":"div-ps-ad-pave_bas"},{"id":118370,"tagId":"div-ps-ad-pave_article0"},{"id":97825,"tagId":"div-ps-ad-pave_article"},{"id":103885,"tagId":"div-ps-ad-pave_article2"},{"id":103886,"tagId":"div-ps-ad-pave_article3"},{"id":119437,"tagId":"div-ps-ad-pave_article4"},{"id":119438,"tagId":"div-ps-ad-pave_article5"},{"id":119439,"tagId":"div-ps-ad-pave_article6"}]},"target":"GrNM_rubrique=education;GrNM_rubrique=faits-de-societe;GrNM_locale=antibes;GrNM_connected=no;GrNM_subscriber_digital=no;GrNM_subscriber_print=no;article_id=926616;version_beta=false"}
# </script>
# <meta content="Éducation,Faits de société" name="keywords">
# <meta content="false" property="article:opinion">
# <meta content="locked" property="article:content_tier"/>
# <meta content="region:fra" property="article:location"/>
# <meta content="city:Antibes" property="article:location"/>
# <link href="https://www.nicematin.com/amp/education/on-fait-ce-stage-par-depit-clairement-926616" rel="amphtml">
# <link href="https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616" rel="canonical">
# <meta content="&quot;On le fait par dépit, clairement&quot;: la galère des lycéens de seconde à Antibes pour trouver un stage de fin d'année" itemprop="headline" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616" property="og:url"/>
# <meta content="https://fyooyzbm.filerobot.com/v7/afp/13592355-cjE5cx54.jpg?vh=ffd618&amp;ci_seal=897cd3fec2" property="og:image"/>
# <meta content="Devant le lycée Jacques-Audiberti, les élèves sortent les uns après les autres. C’est la récréation, l’une des dernières avant la fin de l’année.
# Pour les classes de seconde générale et technologique, la fin de l’année ne se déroulera pas au lycée, mais en milieu professionnel, pour un stage de de" name="description" property="og:description"/>
# <meta content="fr_FR" property="og:locale"/>
# <meta content="439896932851471" property="fb:app_id"/>
# <meta content="Nice-Matin" property="og:site_name"/>
# <meta content="La rédaction" property="article:author"/>
# <meta content="2024-06-10T08:45:00+02:00" property="article:published_time"/><meta content="2024-06-10T08:45:00+02:00" property="article:modified_time"/> <script type="application/ld+json">
# [
#     {
#         "@context": [
#             "http://schema.org",
#             {
#                 "mydomain": "https://www.nicematin.com"
#             }
#         ],
#         "@type": "NewsArticle",
#         "mainEntityOfPage": {
#             "@type": "WebPage",
#             "@id": "https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616"
#         },
#         "headline": "\"On le fait par d\u00e9pit, clairement\": la gal\u00e8re des lyc\u00e9ens de seconde \u00e0 Antibes pour trouver un stage de fin d'ann\u00e9e",
#         "alternativeHeadline": "Pour la premi\u00e8re fois, les \u00e9l\u00e8ves de seconde devront faire un stage. Certains essuient des refus et se rabattent sur des secteurs qui ne sont pas en lien avec leurs \u00e9tudes.",
#         "description": "Pour la premi\u00e8re fois, les \u00e9l\u00e8ves de seconde devront faire un stage. Certains essuient des refus et se rabattent sur des secteurs qui ne sont pas en lien avec leurs \u00e9tudes.",
#         "datePublished": "2024-06-10T08:45:00+02:00",
#         "articleSection": "\u00c9ducation",
#         "keywords": [],
#         "author": {
#             "@type": "Person",
#             "JobTitle": "Journaliste",
#             "name": "Nathan Beaufils"
#         },
#         "publisher": {
#             "@type": "NewsMediaOrganization",
#             "name": "Nice-Matin",
#             "logo": {
#                 "@type": "ImageObject",
#                 "url": "https://cdn.assets01.nicematin.com/build/imgs/titles/title_nm.f937a794.png",
#                 "height": 60,
#                 "width": 399
#             }
#         },
#         "image": {
#             "@type": "ImageObject",
#             "url": "https://fyooyzbm.filerobot.com/v7/afp/13592355-cjE5cx54.jpg?vh=ffd618&ci_seal=897cd3fec2&w=1200&h=675",
#             "height": 675,
#             "width": 1200
#         },
#         "isAccessibleForFree": false,
#         "hasPart": {
#             "@type": "WebPageElement",
#             "isAccessibleForFree": false,
#             "cssSelector": ".paywall-abo",
#             "value": "Abonnez-vous et acc\u00e9dez \u00e0 toute l\u2019info dans un espace sans publicit\u00e9"
#         },
#         "isPartOf": {
#             "@type": [
#                 "CreativeWork",
#                 "Product"
#             ],
#             "name": "Nice-Matin",
#             "productID": ":subscriber"
#         }
#     },
#     {
#         "@context": "https://schema.org",
#         "@type": "WebSite",
#         "name": "Nice-Matin",
#         "alternateName": "Actualit\u00e9s et infos en direct - Nice-Matin",
#         "url": "https://www.nicematin.com/",
#         "image": "https://cdn.assets01.nicematin.com/build/imgs/titles/title_nm.f937a794.png"
#     }
# ]
# </script>
# <script type="text/javascript">
#         var _sf_async_config = _sf_async_config || {};
#         /** CONFIGURATION START **/
#         _sf_async_config.uid = 65758;
#         _sf_async_config.domain = 'nicematin.com';
#         _sf_async_config.path =  window.location.pathname;
#                 _sf_async_config.flickerControl = false;
#                 /** CONFIGURATION END **/
#         var _sf_startpt = (new Date()).getTime();
#         </script>
# <script async="" src="//static.chartbeat.com/js/chartbeat_mab.js"></script>
# <link href="https://cdn.assets03.nicematin.com/build/css/freemium.a6dc255d.css" rel="stylesheet"/>
# <script type="text/javascript">
#           window.dataLayer = window.dataLayer || [];
#           dataLayer.push({
#             'user_id': null,
#             'user_id_email': null,
#             'user_is_connected': 'false',
#             'environnement': 'prod',
#             'user_is_subscriber': 'false',
#             'espace_client': null,
#             'profil_abo': null,
#             'offre_commercial': null,
#             'date_first_connexion_ec': null,
#             'list_name': null,
#                 'list_name': null,
#
#
#                         'page_template': 'article_detail',
#                     'post_subscriber': true,
#
#     'post_sponsored': false,
#     'post_alert': false,
#     'post_solution': false,
#     'post_info': true,
#
#     'post_format': 'default',
#     'post_content': '',
#     'post_location_city': "Antibes",
#     'post_location_territory': '',
#     'post_tags': '',
#     'post_category_level_1': "\u00C9ducation",
#     'post_category_level_2': 'Faits de société',
#     'post_publication_date': '2024-06-10T08:45:00+02:00',
#         'post_publication_date_days': 1,
#
#     'post_modification_date': '2024-06-10T08:45:00+02:00',
#         'post_modification_date_days': 1,
#
#     'post_author': 'Nathan Beaufils',
#     'post_credits': 'Photo N. B.',
#     'post_length_words': 486,
#     'post_id': "926616",
#
#     'post_episod_name': "\u0022On\u0020le\u0020fait\u0020par\u0020d\u00E9pit,\u0020clairement\u0022\u003A\u0020la\u0020gal\u00E8re\u0020des\u0020lyc\u00E9ens\u0020de\u0020seconde\u0020\u00E0\u0020Antibes\u0020pour\u0020trouver\u0020un\u0020stage\u0020de\u0020fin\u0020d\u0027ann\u00E9e",
#           });
#         </script>
# <!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
#     w[l] = w[l] || [];
#     w[l].push({
#       'gtm.start':
#         new Date().getTime(), event: 'gtm.js'
#     });
#     var f = d.getElementsByTagName(s)[0],
#       j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#     j.async = true;
#     j.src =
#       'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#     f.parentNode.insertBefore(j, f);
#   })(window, document, 'script', 'dataLayer', 'GTM-MNNXJVMD');</script>
# <!-- End Google Tag Manager -->
# <script crossorigin="anonymous" integrity="sha256-o88AwQnZB+VDvE9tvIXrMQaPlFFSUTR+nldQm1LuPXQ=" src="https://code.jquery.com/jquery-3.6.1.min.js"></script>
# <script type="text/javascript">
#
#   document.addEventListener("DOMContentLoaded", function () {
#
#     function datalayerPush(click = "", click_chapter1 = "", click_chapter2 = "") {
#       window.dataLayer.push({
#         event: "user_action", // user_action
#         click: click, // key name
#         click_chapter1: click_chapter1, // url - chapt1 (AT)
#         click_chapter2: click_chapter2, // label - chapt2 (AT)
#       });
#     }
#
#     function selectorEvent(selector, callback, trigger = "click") {
#       let element = document.querySelectorAll(selector);
#       element.forEach((data) => data.addEventListener(trigger, callback));
#     }
#
#     // Clicks Header
#     const linkHeader = document.querySelectorAll("#menu-header a");
#     const linkHeaderFirstLevel = document.querySelectorAll("span.heading-title");
#
#     if (linkHeader) {
#       linkHeader.forEach(e => e.addEventListener("click", function (event) {
#         trackingHeaderLink(event);
#       }));
#     }
#
#     if (linkHeaderFirstLevel) {
#       linkHeaderFirstLevel.forEach(e => e.addEventListener("click", function (event) {
#         trackingHeaderLink(event);
#       }));
#     }
#
#     function trackingHeaderLink(event) {
#       let eventName, eventAction, eventLabel; // Declare variables here
#
#       if(event.currentTarget.classList.contains("article-title")) {
#         // Click on article title
#         eventName = event.currentTarget.getAttribute("data-target") || 'click_article_preview_title';
#         eventAction = event.currentTarget.href;
#         eventLabel =  event.currentTarget.className;
#       } else if(event.currentTarget.classList.contains("header-article-preview")){
#         // Click on article image
#         eventName = event.currentTarget.getAttribute("data-target") || 'click_article_preview_image';
#         eventAction = event.currentTarget.href;
#         eventLabel = event.currentTarget.className;
#       } else if(event.currentTarget.classList.contains("item-journal")) {
#         // Click on newspaper item
#         eventName = "newspaper_header";
#         eventAction = event.currentTarget.href;
#         eventLabel = event.currentTarget.className;
#       } else {
#         // All others links
#         eventName = event.target.innerText.toLowerCase();
#         eventName = eventName.charAt(0).toUpperCase() + eventName.slice(1);
#         eventAction = event.target.href;
#         eventLabel =  event.target.className;
#       }
#       datalayerPush(eventName, eventAction, eventLabel);
#     }
#
#     // Clicks Burger
#     selectorEvent(
#       "#menu-burger-wrapper .menu-burger-links a",
#       (e) => {
#         let eventName = e.target.innerText || 'click_burger';
#         datalayerPush(eventName, e.target.href, e.target.className)
#       }
#     );
#
#     function handleMenuItemClick(level, chapter2) {
#       return function (event) {
#         if (event.target.dataset.level === level) {
#           window.dataLayer.push({
#             'event': 'user_action',
#             'click': 'Burger_link',
#             'click_chapter1': event.target.innerText || '',
#             'click_chapter2': chapter2
#           });
#         }
#       };
#     }
#
#     for (let level = 1; level <= 4; level++) {
#       const strLvl = {1: "first", 2: "second", 3: "third", 4: "fourth"}
#       const niveau = document.querySelectorAll(`.menu-burger-submenu .menu-burger-submenu--${strLvl[level]}_level`);
#       if (niveau) {
#         niveau.forEach((e) => {
#           e.addEventListener('click', handleMenuItemClick(`level-${strLvl[level]}`, `Burger_link_${strLvl[level]}`));
#         });
#       }
#     }
#
#     // Clicks Footer
#     selectorEvent(
#       "#footer a",
#       (e) => {
#         let eventName = e.target.innerText || 'click_footer';
#         datalayerPush(eventName, e.target.href, e.target.className)
#       }
#     );
#
#     // Clicks Articles
#     selectorEvent(
#       "#article-info a",
#       (e) => {
#         let eventName = e.target.innerText || 'click_article';
#         datalayerPush(eventName, e.target.href, e.target.className)
#       }
#     );
#
#     // Clicks Une Burger
#     selectorEvent(
#       "#menu-burger-wrapper .menu-burger-newspaper a",
#       (e) => {
#         datalayerPush("newspaper_burger", e.currentTarget.href, e.currentTarget.className)
#       }
#     );
#   });
# </script>
# <script src="https://cdn.assets03.nicematin.com/build/runtime.4b9cb7aa.js"></script><script src="https://cdn.assets01.nicematin.com/build/8943.cc742ecb.js"></script><script src="https://cdn.assets02.nicematin.com/build/js/freemium/datalayer.a9ad865c.js"></script>
# <script type="text/javascript">
# var userDataLayer = []
# dataLayer.push(userDataLayer);</script>
# <!-- AB Tasty -->
# <script src="https://try.abtasty.com/603827b25c3d5d62f85ee3425eea0ee9.js" type="text/javascript"></script>
# <!-- END AB Tasty -->
# <script type="text/javascript">
#         var batchConf = {
#             serviceWorkerPathOverride: "/build/js/batchsdk-worker-loader.js",
#             apiKey: 'C424BC1EF90948AAB4419825D0C2E902',
#             subdomain: 'nicematin',
#             authKey: '2.nS7fXyXSnhDa/eA7piks08epgmD/B3H2prtlZhX4UEU=',
#                         vapidPublicKey: 'BJ63KPHtpzS624s81gkgAFuIYzfNAOlPAObJIZ3ACyNDmusYQzo2Ft8gLKOjZCytsCkOPAhlTKDb1+XxFgaTMBU='
#         };
#         var batchCustomerUserId = null;
#     </script>
# <meta content="nicematin" name="pbstck_context:site_name"/>
# <meta content="yes" name="pbstck_context:paywall"/>
# <meta content="no" name="ad:version_beta"/>
# <meta content="article" name="pbstck_context:page_type"/>
# <meta content="926616" name="ad:article_id"/>
# <meta content="education,faits-de-societe" name="ad:GrNM_rubrique"/>
# <meta content="antibes" name="ad:GrNM_locale"/>
# <meta content="no" name="ad:GrNM_connected"/>
# <meta content="no" name="ad:GrNM_subscriber_digital"/>
# <meta content="no" name="ad:GrNM_subscriber_print"/>
# <script>
#   let metaDevice = document.createElement('meta');
#   metaDevice.name = "pbstck_context:device";
#   metaDevice.content = screen.width <= 1024 ? "webmobile" : "desktop";
#   document.head.appendChild(metaDevice)
# </script>
# <script type="text/javascript">
# window.dataLayer = window.dataLayer || [];
# const nmDataLayerNavigation = screen.width <= 1024 ? {navigation: "webmobile"} : {navigation: "desktop"};
# const nmDataLayerInfos = {"editor_group":"Groupe Nice-Matin","environnement":"nicematin","title_article":"\"On le fait par d\u00e9pit, clairement\": la gal\u00e8re des lyc\u00e9ens de seconde \u00e0 Antibes pour trouver un stage de fin d'ann\u00e9e","keywords":[],"topics":["\u00c9ducation"],"publication_date":"20240610","media_enrichment":["image"],"blocked_article":"","premium_article":true,"length_word":486,"nb_paragraph":14,"reading_time":"","sponsored":false,"sponsored_by":"","INSEE_code":"06004","zipcode":"06160","departement_id":"06","departement_label":"Alpes-Maritimes","region":"Provence-Alpes-C\u00f4te d'Azur","city":"Antibes","editor_user_id":"","email_hashed":"","inscription_date":"","user_connected":false,"user_subscriber":false,"type_subscription":[]}
# const nmDataLayer = {...nmDataLayerInfos, ...nmDataLayerNavigation}
# dataLayer.push(nmDataLayer);
# dataLayer.push({"nm_data_layer": nmDataLayer});</script>
# </link></link></meta></meta></meta></link></link></head>
# <body class="article-details">
# <!-- script Gravity -->
# <script type="text/javascript">
# // -------- BEGIN TAG ALLIANCE GRAVITY --------
# var grvt_customProperties = {};
# var grvt_siteToken = 'nice_matin21';
# var grvt_processingToken = 'five-arizona';
# var script = document.createElement('script');
# script.src = "https://tag.agrvt.com/tag/v2/wrapper.js";
# document.head.appendChild(script);
# // -------- END TAG ALLIANCE GRAVITY --------
# </script>
# <!-- end script Gravity -->
# <div id="menu-header-wrapper">
# <header class="nm" data-has-ribbon-bottom="" id="menu-header">
# <nav class="ribbon-top">
# <ul class="left">
# <li class="burger-menu">
# <span class="item item-big" id="burger-menu-button-toggler">
# <i class="icon-burger"></i>
# </span>
# </li>
# <li class="hide-down-md hide-up-xl">
# <a class="item item-hover item-journal header-link" href="/newspapers">
# <img alt="Journal du jour" src="https://fyooyzbm.filerobot.com/v7/https://static01.nicematin.com/media/staticjel/xlarge/nicematin/nice/2024-06-11.jpg?w=70&amp;h=50&amp;gravity=north"/>
# <p>Lire le <br/>journal</p>
# </a>
# </li>
# <li class="hide-down-xl">
# <a class="item item-big search header-link" href="https://www.nicematin.com/recherche">
# <i class="icon-search"></i>
# </a>
# </li>
# <li class="hide-down-xl">
# <i class="separator"></i>
# </li>
# <li class="hide-down-xl">
# <a class="item item-hover item-journal header-link" href="/newspapers">
# <img alt="Journal du jour" src="https://fyooyzbm.filerobot.com/v7/https://static01.nicematin.com/media/staticjel/xlarge/nicematin/nice/2024-06-11.jpg?w=70&amp;h=50&amp;gravity=north"/>
# <p>Lire le <br/>journal</p>
# </a>
# </li>
# </ul>
# <ul class="middle">
# <li>
# <a class="item logo" href="https://www.nicematin.com/">
# <img alt="Nice-Matin" src="https://cdn.assets01.nicematin.com/build/imgs/titles/title_nm.f937a794.png"/>
# </a>
# </li>
# </ul>
# <ul class="right">
# <li class="hide-down-lg">
# <a class="item item-hover header-link" href="https://www.nicematin.com/user/login?_redirect_target_path=https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616" rel="nofollow">
# <i class="icon-user"></i>
# <p>Se connecter</p>
# </a>
# </li>
# <li>
# <a class="button yellow header-link" data-label="Abonnez-vous" href="https://abo.nicematin.com/abonnement/formules?lastpage_abo=https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616&amp;lastclic_abo=Abonnez-vous&amp;lastclic_1er_niveau_abo=https://abo.nicematin.com/abonnement/formules&amp;lastclic_2e_niveau_abo=header-abo-link">Abonnez-vous</a>
# </li>
# </ul>
# </nav>
# <nav class="ribbon-bottom" id="menu-header-ribbon-bottom">
# <ul>
# <li class="header-link-container">
# <a class="header-link-primary" href="https://www.nicematin.com/sujet/elections-legislatives">
#                                     Elections législatives
#                                 </a>
# </li>
# <li class="dropdown header-link-container">
# <span class="heading-title">Actualités</span>
# <div class="submenu">
# <div class="submenu-content content">
# <div class="content-row">
# <div>
# <h4 class="header-sublink">
#                                                             Actualités
#                                                         </h4>
# <ul class="content-list">
# <li class="">
# <a class="header-link-secondary" href="https://www.nicematin.com/sujet/faits-de-societe">
#                                                                                 Société
#                                                                             </a>
# </li>
# <li class="">
# <a class="header-link-secondary" href="https://www.nicematin.com/sujet/faits-divers">
#                                                                                 Faits divers
#                                                                             </a>
# </li>
# <li class="">
# <a class="header-link-secondary" href="https://www.nicematin.com/sujet/economie">
#                                                                                 Économie
#                                                                             </a>
# </li>
# <li class="">
# <a class="header-link-secondary" href="https://www.nicematin.com/sujet/politique">
#                                                                                 Politique
#                                                                             </a>
# </li>
# <li class="">
# <a class="header-link-secondary" href="https://www.nicematin.com/sujet/sport">
#                                                                                 Sports
#                                                                             </a>
# </li>
# <li class="">
# <a class="header-link-secondary" href="https://www.nicematin.com/sujet/sante">
#                                                                                 Santé
#                                                                             </a>
# </li>
# <li class="">
# <a class="header-link-secondary" href="https://www.nicematin.com/sujet/ogcnice">
#                                                                                 OGC Nice
#                                                                             </a>
# </li>
# <li class="">
# <a class="header-link-secondary" href="https://www.nicematin.com/sujet/opinion">
#                                                                                 Opinion
#                                                                             </a>
# </li>
# <li class="">
# <a class="header-link-secondary" href="https://www.nicematin.com/sujet/culture">
#                                                                                 Culture
#                                                                             </a>
# </li>
# <li class="">
# <a class="header-link-secondary" href="https://www.nicematin.com/sujet/jeux-olympiques">
#                                                                                 Jeux Olympiques
#                                                                             </a>
# </li>
# </ul>
# </div>
# <div class="article-preview">
# <a class="rearrange header-article-preview" data-target="Actualités_article_preview_image1" href="https://www.nicematin.com/faits-divers/feu-de-vidauban-trois-hameaux-en-cours-d-evacuation-au-plan-de-la-tour-926972">
# <figure>
# <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="protec/DATA_ART_13607207-ll1hHzBs.jpg?vh=bfe599&amp;ci_seal=9ae4ebaf66" operation="crop"/>
# </figure>
# <div class="block-title">
# <div class="thematic-container">
# <div class="classification">
# <a class="thematic" href="/sujet/faits-divers" target="_blank">Faits divers</a>
# </div>
# </div>
# <a class="article-title" data-target="Actualités_article_preview_title1" href="https://www.nicematin.com/faits-divers/feu-de-vidauban-trois-hameaux-en-cours-d-evacuation-au-plan-de-la-tour-926972"><h3>Feu dans le massif des Maures: trois hameaux en cours d’évacuation au Plan-de-la-Tour</h3></a>
# </div>
# </a> </div>
# <div class="article-preview">
# <a class="rearrange header-article-preview" data-target="Actualités_article_preview_image2" href="https://www.nicematin.com/faits-divers/600-hectares-de-foret-parcourus-des-dizaines-devacuations-on-fait-le-point-sur-lincendie-en-cours-dans-le-massif-des-maures-926963">
# <figure>
# <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="IMG-20240611-WA0021-5mPUgOmz.jpg?vh=228190&amp;ci_seal=5d5c2bffac" operation="crop"/>
# </figure>
# <div class="block-title">
# <div class="thematic-container">
# <div class="classification">
# <a class="thematic" href="/sujet/faits-divers" target="_blank">Faits divers</a>
# </div>
# </div>
# <a class="article-title" data-target="Actualités_article_preview_title2" href="https://www.nicematin.com/faits-divers/600-hectares-de-foret-parcourus-des-dizaines-devacuations-on-fait-le-point-sur-lincendie-en-cours-dans-le-massif-des-maures-926963"><h3>600 hectares de forêt parcourus, des dizaines d'évacuations... On fait le point sur l'incendie en cours dans le massif des Maures</h3></a>
# </div>
# </a> </div>
# <div class="article-preview">
# <a class="rearrange header-article-preview" data-target="Actualités_article_preview_image3" href="https://www.nicematin.com/faits-de-societe/que-pensent-les-nicois-de-l-alliance-proposee-par-eric-ciotti-au-rn--926966">
# <figure>
# <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="protec/DATA_ART_13605978-DiT83VLT.jpg?vh=77c5c0&amp;ci_seal=1b2c3cf55d" operation="crop"/>
# </figure>
# <div class="block-title">
# <div class="thematic-container">
# <i class="icon-lock"></i>
# <div class="classification">
# <a class="thematic" href="/sujet/faits-de-societe" target="_blank">Faits de société</a>
# </div>
# </div>
# <a class="article-title" data-target="Actualités_article_preview_title3" href="https://www.nicematin.com/faits-de-societe/que-pensent-les-nicois-de-l-alliance-proposee-par-eric-ciotti-au-rn--926966"><h3>Que pensent les Niçois de l’alliance proposée par Eric Ciotti au RN? On est allé leur demander</h3></a>
# </div>
# </a> </div>
# <div class="article-preview">
# <a class="rearrange header-article-preview" data-target="Actualités_article_preview_image4" href="https://www.nicematin.com/politique/est-il-possible-de-voter-aux-elections-legislatives-si-on-a-18-ans-avant-le-30-juin-ou-entre-les-deux-tours-926948">
# <figure>
# <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="maxmatinarch509593-K6zwqDBg.jpg?vh=9f4d4e&amp;ci_seal=b948232ed3" operation="crop"/>
# </figure>
# <div class="block-title">
# <div class="thematic-container">
# <div class="classification">
# <a class="thematic" href="/sujet/politique" target="_blank">Politique</a>
# </div>
# </div>
# <a class="article-title" data-target="Actualités_article_preview_title4" href="https://www.nicematin.com/politique/est-il-possible-de-voter-aux-elections-legislatives-si-on-a-18-ans-avant-le-30-juin-ou-entre-les-deux-tours-926948"><h3>Est-il possible de voter aux élections législatives si on a 18 ans avant le 30 juin ou entre les deux tours?</h3></a>
# </div>
# </a> </div>
# </div>
# </div>
# </div>
# </li>
# <li class="header-link-container">
# <a class="header-link-primary" href="https://www.nicematin.com/sujet/video">
#                                     Vidéos
#                                 </a>
# </li>
# <li class="header-link-container">
# <a class="header-link-primary" href="https://www.nicematin.com/sujet/faits-divers">
#                                     Faits-divers
#                                 </a>
# </li>
# <li class="header-link-container">
# <a class="header-link-primary" href="https://www.nicematin.com/sujet/diane-emploi">
#                                     Emploi
#                                 </a>
# </li>
# <li class="dropdown header-link-container">
# <span class="heading-title">Ma ville</span>
# <div class="submenu">
# <div class="submenu-content content">
# <div class="content-row">
# <div>
# <h4 class="header-sublink">
#                                                             Ma ville
#                                                         </h4>
# <ul class="content-list">
# <li class="">
# <a class="header-link-secondary" data-label="Nice" href="https://www.nicematin.com/ville/nice">
#                                                                             Nice
#                                                                         </a>
# </li>
# <li class="">
# <a class="header-link-secondary" data-label="Saint-Laurent-du-Var" href="https://www.nicematin.com/commune/saint-laurent-du-var">
#                                                                             Saint-Laurent-du-Var
#                                                                         </a>
# </li>
# <li class="">
# <a class="header-link-secondary" data-label="Cagnes-sur-Mer" href="https://www.nicematin.com/ville/cagnes">
#                                                                             Cagnes-sur-Mer
#                                                                         </a>
# </li>
# <li class="">
# <a class="header-link-secondary" data-label="Cannes" href="https://www.nicematin.com/ville/cannes">
#                                                                             Cannes
#                                                                         </a>
# </li>
# <li class="">
# <a class="header-link-secondary" data-label="Antibes" href="https://www.nicematin.com/ville/antibes">
#                                                                             Antibes
#                                                                         </a>
# </li>
# <li class="">
# <a class="header-link-secondary" data-label="Grasse" href="https://www.nicematin.com/ville/grasse">
#                                                                             Grasse
#                                                                         </a>
# </li>
# <li class="">
# <a class="header-link-secondary" data-label="Menton" href="https://www.nicematin.com/ville/menton">
#                                                                             Menton
#                                                                         </a>
# </li>
# <li class="">
# <a class="header-link-secondary" data-label="Monaco" href="https://www.nicematin.com/ville/monaco">
#                                                                             Monaco
#                                                                         </a>
# </li>
# <li class="">
# <a class="header-link-secondary" data-label="Vallées" href="https://www.nicematin.com/ville/vallees">
#                                                                             Vallées
#                                                                         </a>
# </li>
# </ul>
# </div>
# <div class="article-preview">
# <a class="rearrange header-article-preview" data-target="Ma ville_article_preview_image1" href="https://www.nicematin.com/faits-divers/feu-de-vidauban-trois-hameaux-en-cours-d-evacuation-au-plan-de-la-tour-926972">
# <figure>
# <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="protec/DATA_ART_13607207-ll1hHzBs.jpg?vh=bfe599&amp;ci_seal=9ae4ebaf66" operation="crop"/>
# </figure>
# <div class="block-title">
# <div class="thematic-container">
# <div class="classification">
# <a class="thematic" href="/sujet/faits-divers" target="_blank">Faits divers</a>
# </div>
# </div>
# <a class="article-title" data-target="Ma ville_article_preview_title1" href="https://www.nicematin.com/faits-divers/feu-de-vidauban-trois-hameaux-en-cours-d-evacuation-au-plan-de-la-tour-926972"><h3>Feu dans le massif des Maures: trois hameaux en cours d’évacuation au Plan-de-la-Tour</h3></a>
# </div>
# </a> </div>
# <div class="article-preview">
# <a class="rearrange header-article-preview" data-target="Ma ville_article_preview_image2" href="https://www.nicematin.com/faits-divers/600-hectares-de-foret-parcourus-des-dizaines-devacuations-on-fait-le-point-sur-lincendie-en-cours-dans-le-massif-des-maures-926963">
# <figure>
# <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="IMG-20240611-WA0021-5mPUgOmz.jpg?vh=228190&amp;ci_seal=5d5c2bffac" operation="crop"/>
# </figure>
# <div class="block-title">
# <div class="thematic-container">
# <div class="classification">
# <a class="thematic" href="/sujet/faits-divers" target="_blank">Faits divers</a>
# </div>
# </div>
# <a class="article-title" data-target="Ma ville_article_preview_title2" href="https://www.nicematin.com/faits-divers/600-hectares-de-foret-parcourus-des-dizaines-devacuations-on-fait-le-point-sur-lincendie-en-cours-dans-le-massif-des-maures-926963"><h3>600 hectares de forêt parcourus, des dizaines d'évacuations... On fait le point sur l'incendie en cours dans le massif des Maures</h3></a>
# </div>
# </a> </div>
# <div class="article-preview">
# <a class="rearrange header-article-preview" data-target="Ma ville_article_preview_image3" href="https://www.nicematin.com/faits-de-societe/que-pensent-les-nicois-de-l-alliance-proposee-par-eric-ciotti-au-rn--926966">
# <figure>
# <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="protec/DATA_ART_13605978-DiT83VLT.jpg?vh=77c5c0&amp;ci_seal=1b2c3cf55d" operation="crop"/>
# </figure>
# <div class="block-title">
# <div class="thematic-container">
# <i class="icon-lock"></i>
# <div class="classification">
# <a class="thematic" href="/sujet/faits-de-societe" target="_blank">Faits de société</a>
# </div>
# </div>
# <a class="article-title" data-target="Ma ville_article_preview_title3" href="https://www.nicematin.com/faits-de-societe/que-pensent-les-nicois-de-l-alliance-proposee-par-eric-ciotti-au-rn--926966"><h3>Que pensent les Niçois de l’alliance proposée par Eric Ciotti au RN? On est allé leur demander</h3></a>
# </div>
# </a> </div>
# <div class="article-preview">
# <a class="rearrange header-article-preview" data-target="Ma ville_article_preview_image4" href="https://www.nicematin.com/politique/est-il-possible-de-voter-aux-elections-legislatives-si-on-a-18-ans-avant-le-30-juin-ou-entre-les-deux-tours-926948">
# <figure>
# <img alt="" ci-params="gravity=auto" ci-sizes="{
#     '(max-width: 768px)':  { w: 150, h: 190 },
#     '(min-width: 768px)': { w: 150, h: 190 }
#   }" ci-src="maxmatinarch509593-K6zwqDBg.jpg?vh=9f4d4e&amp;ci_seal=b948232ed3" operation="crop"/>
# </figure>
# <div class="block-title">
# <div class="thematic-container">
# <div class="classification">
# <a class="thematic" href="/sujet/politique" target="_blank">Politique</a>
# </div>
# </div>
# <a class="article-title" data-target="Ma ville_article_preview_title4" href="https://www.nicematin.com/politique/est-il-possible-de-voter-aux-elections-legislatives-si-on-a-18-ans-avant-le-30-juin-ou-entre-les-deux-tours-926948"><h3>Est-il possible de voter aux élections législatives si on a 18 ans avant le 30 juin ou entre les deux tours?</h3></a>
# </div>
# </a> </div>
# </div>
# </div>
# </div>
# </li>
# <li class="dropdown header-link-container">
# <span class="heading-title">Services</span>
# <div class="submenu">
# <div class="submenu-content content">
# <div class="content-row">
# <div class="services-container">
# <ul class="submenu-col">
# <li>
# <h4 class="header-sublink">
#                                                                         Annonces
#                                                                     </h4>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Avis de décès" href="/carnet-avis-deces?dpt=06&amp;commune=Toutes+les+communes">
#                                                                             Avis de décès
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Annonces légales" href="/annonces/annonces-legales/">
#                                                                             Annonces légales
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Marchés publics" href="https://www.francemarches.com/nice-matin">
#                                                                             Marchés publics
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Emploi" href="/sujet/diane-emploi">
#                                                                             Emploi
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Déposer une petite annonce" href="/petites-annonces">
#                                                                             Déposer une petite annonce
#                                                                         </a>
# </li>
# </ul>
# <ul class="submenu-col">
# <li>
# <h4 class="header-sublink">
#                                                                         Nos services
#                                                                     </h4>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Newsletters" href="/newsletters">
#                                                                             Newsletters
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Programme TV" href="https://www.diverto.tv/programme-tv" target="_blank">
#                                                                             Programme TV
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Météo" href="/sujet/meteo">
#                                                                             Météo
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Vos déclarations" href="/saintvalentin">
#                                                                             Vos déclarations
#                                                                         </a>
# </li>
# </ul>
# <ul class="submenu-col">
# <li>
# <h4 class="header-sublink">
#                                                                         Nos partenaires
#                                                                     </h4>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Côte d'Azur Éco" href="/sujet/cotedazur-eco">
#                                                                             Côte d'Azur Éco
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Côte d'Azur Santé" href="/sujet/cotedazur-sante">
#                                                                             Côte d'Azur Santé
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Nos Ambassadeurs" href="/sujet/nos-ambassadeurs">
#                                                                             Nos Ambassadeurs
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Région Sud" href="/sujet/le-soleil-se-leve-au-sud">
#                                                                             Région Sud
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Métropole Nice Côte d’Azur" href="/sujet/metropole-nice-cote-d-azur">
#                                                                             Métropole Nice Côte d’Azur
#                                                                         </a>
# </li>
# </ul>
# <ul class="submenu-col">
# <li>
# <h4 class="header-sublink">
#                                                                         Nos suppléments
#                                                                     </h4>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Guide des Vins" href="/sujet/guide-des-vins">
#                                                                             Guide des Vins
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Guide Été" href="/sujet/guide-ete">
#                                                                             Guide Été
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Nouvelle Ère" href="/sujet/nouvelle-ere">
#                                                                             Nouvelle Ère
#                                                                         </a>
# </li>
# </ul>
# <ul class="submenu-col">
# <li>
# <h4 class="header-sublink">
#                                                                         Nos évènements
#                                                                     </h4>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Tour des Alpes-Maritimes" href="/cyclisme/tour-des-alpes-maritimes">
#                                                                             Tour des Alpes-Maritimes
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Classic Var" href="/cyclisme/classic-var">
#                                                                             Classic Var
#                                                                         </a>
# </li>
# <li>
# <a class="header-link-secondary" data-label="Golf" href="/sujet/golf">
#                                                                             Golf
#                                                                         </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="header-link-container">
# <a class="header-link current-topic" href="https://www.nicematin.com/sujet/jeux-olympiques">
#                             JO 2024
#                         </a>
# </li>
# </ul>
# </nav>
# <div class="no-mobile">
# <a href="https://abo.nicematin.com/lp/numerique?lastpage_abo=https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616&amp;lastclic_abo=ABONNEZ-VOUS&amp;lastclic_1er_niveau_abo=https://abo.nicematin.com/abonnement/formules&amp;lastclic_2e_niveau_abo=promotionnal-header-banner">
# <div id="promotionnal-header-banner">
# <div class="promotionnal-container">
# <div class="promotionnal-message">Les articles en illimité + le journal numérique &gt;&gt; ABONNEZ-VOUS</div>
# <a class="close" href="#"><i class="icon-close"></i></a>
# </div>
# </div>
# </a>
# </div>
# </header>
# </div>
# <div id="menu-burger-wrapper">
# <nav class="menu-burger">
# <ul class="menu-burger-icons">
# <li><a class="menu-burger-close item-big" href="#"><i class="icon-close"></i></a></li>
# </ul>
# <ul class="menu-burger-research">
# <form action="https://www.nicematin.com/recherche" class="search-container">
# <i class="icon-search"></i>
# <input id="nm_search_input" name="search" placeholder="Recherche" type="text"/>
# </form>
# </ul>
# <ul class="menu-burger-newspaper">
# <li>
# <a href="/newspapers"><img alt="Journal du jour" src="https://fyooyzbm.filerobot.com/v7/https://static01.nicematin.com/media/staticjel/xlarge/nicematin/nice/2024-06-11.jpg?w=115&amp;h=80&amp;gravity=north"/></a>
# </li>
# <li class="menu-burger-newspaper-date">
# <span>Mardi 11 juin</span>
# <a class="menu-burger-newspaper-button" href="/newspapers">
#                         Lire le journal
#                     </a>
# </li>
# </ul>
# <ul class="menu-burger-links">
# <li class="hide-down-md">
# <a class="icon-user burger-link" href="https://www.nicematin.com/user/login?_redirect_target_path=https://www.nicematin.com/user/profil">
#                                                     Se connecter
#                                             </a>
# </li>
# <li>
# <a class="solution burger-link" href="/folders">
#                         Dossiers Solutions
#                     </a>
# </li>
# <li>
# <a class="tv burger-link" href="https://www.diverto.tv/programme-tv" target="_blank">
#                         Programme TV
#                     </a>
# </li>
# <li class="hide-down-md">
# <a class="podcast burger-link" href="https://www.nicematin.com/podcasts/">
#                         Podcast
#                     </a>
# </li>
# <li class="hide-down-md">
# <a class="videos2 burger-link" href="https://www.nicematin.com/sujet/video">
#                         Vidéos
#                     </a>
# </li>
# <li>
# <a class="newsletters burger-link" href="/newsletters">
#                         Newsletters
#                     </a>
# </li>
# <li class="highlight">
# <a class="live burger-link" href="/sujet/jeux-olympiques">
#                         JO2024
#                     </a>
# </li>
# </ul>
# <ul class="menu-burger-submenu">
# ...
# <li><a class="footer-link" href="https://www.nicematin.com/user/login?_redirect_target_path=https://www.nicematin.com/user/cancel/subscription">Résilier mon abonnement</a></li>
# <!--<li><a href="">Nos newsletter</a></li>
#                 <li><a href="">Nos applications</a></li>-->
# </ul>
# </div>
# <div>
# <div class="footer-title"><span>Suivez Nice-Matin sur les réseaux sociaux</span></div>
# <ul class="social">
# <li>
# <a class="footer-link" href="https://www.linkedin.com/company/groupenicematin/" target="_blank">
# <i class="icon-linkedin"></i>
# </a>
# </li>
# <li>
# <a class="footer-link" href="https://twitter.com/Nice_Matin" target="_blank">
# <i class="icon-twitter"></i>
# </a>
# </li>
# <li>
# <a class="footer-link" href="https://www.facebook.com/Page.NiceMatin/" target="_blank">
# <i class="icon-facebook"></i>
# </a>
# </li>
# <li>
# <a class="footer-link" href="https://www.instagram.com/nice_matin" target="_blank">
# <i class="icon-instagram"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <img alt="0" border="0" height="1" src="https://api.optinproject.com/rt/visit/nicematin.gif" width="1">
# </img></footer>
# <script src="//www.ultimedia.com/js/common/smart.js" type="text/javascript"></script>
# <script>
#       var NMConfig = {
#         channel: "nicematin",
#         acronym: "nm",
#         default_img: "nicematin/default.png",
#         path: {"subscription":"https:\/\/www.nicematin.com\/abonnement\/offre\/1055","base_url":{"main":"https:\/\/www.nicematin.com","freemium":"https:\/\/www.nicematin.com","filerobot_cdn":"https:\/\/fyooyzbm.filerobot.com\/v7\/","filerobot_store":"https:\/\/fyooyzbm.airstore.io\/"},"img":["https:\/\/static01.nicematin.com\/media\/npo\/","https:\/\/static02.nicematin.com\/media\/npo\/","https:\/\/static03.nicematin.com\/media\/npo\/","https:\/\/static04.nicematin.com\/media\/npo\/","https:\/\/static05.nicematin.com\/media\/npo\/"],"jel":["https:\/\/static01.nicematin.com\/media\/staticjel\/","https:\/\/static02.nicematin.com\/media\/staticjel\/","https:\/\/static03.nicematin.com\/media\/staticjel\/","https:\/\/static03.nicematin.com\/media\/staticjel\/","https:\/\/static03.nicematin.com\/media\/staticjel\/"],"assets":["https:\/\/cdn.assets01.nicematin.com\/assets\/","https:\/\/cdn.assets02.nicematin.com\/assets\/","https:\/\/cdn.assets03.nicematin.com\/assets\/","https:\/\/cdn.assets04.nicematin.com\/assets\/","https:\/\/cdn.assets05.nicematin.com\/assets\/"],"static":["https:\/\/cdn.static01.nicematin.com\/media\/static\/","https:\/\/cdn.static02.nicematin.com\/media\/static\/","https:\/\/cdn.static03.nicematin.com\/media\/static\/","https:\/\/cdn.static04.nicematin.com\/media\/static\/","https:\/\/cdn.static05.nicematin.com\/media\/static\/"],"offers":["https:\/\/cdn.static01.nicematin.com\/media\/offers\/","https:\/\/cdn.static02.nicematin.com\/media\/offers\/","https:\/\/cdn.static03.nicematin.com\/media\/offers\/","https:\/\/cdn.static04.nicematin.com\/media\/offers\/","https:\/\/cdn.static05.nicematin.com\/media\/offers\/"]},
#                 };
#             var NMAuth = {user: {"userId":0,"isConnected":false,"userEmail":""} };
#       var NMFileRobotConfig = {"enabled":false,"enabledReact":false,"token":"fyooyzbm","domain":"filerobot.com","baseUrl":"https:\/\/store.filerobot.com\/fyooyzbm\/","cdnUrl":"https:\/\/fyooyzbm.filerobot.com\/v7\/","lazyLoading":true,"presets":{"xs":"(max-width: 480px)","sm":"(min-width: 481px)","md":"(min-width: 721px)","lg":"(min-width: 961px)","xl":"(min-width: 1201px)","xw":"(min-width: 1501px)"}};
#       var NMBaseURL = 'https://www.nicematin.com';
#             var pubstackVersion = "43a11954-7d85-4b9f-879a-26e361e03ffa";
#     </script>
# <script src="https://cdn.assets03.nicematin.com/build/1757.13915057.js"></script><script src="https://cdn.assets02.nicematin.com/build/8422.724a5319.js"></script><script src="https://cdn.assets01.nicematin.com/build/5775.e1c31318.js"></script><script src="https://cdn.assets03.nicematin.com/build/3249.c4d5436a.js"></script><script src="https://cdn.assets02.nicematin.com/build/3946.c2f64eb2.js"></script><script src="https://cdn.assets01.nicematin.com/build/js/freemium/app.9db47e47.js"></script>
# <script src="https://cdn.assets01.nicematin.com/build/js/freemium/menu.49608d99.js"></script>
# <script type="text/javascript">
#       window.NMArticleConfig = {
#         'outbrain': 'fac083a3',
#         'isNative': 'false',
#         'isMobile': /Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i.test(navigator.userAgent),
#         'userIsConnected': "false",
#         'userIsSubscriber': "false",
#       };
#     </script>
# <!-- Scaleflex RUM v1.25b -- April 2020, Fails silently for IE -->
# <script type="text/javascript">
#     window.probSpeedHq={process_for:"all",global_cdn_test:!0},function(){try{window.probSpeedHq=window.probSpeedHq||{},window.addEventListener("load",function(){setTimeout(e,1e3)})}catch(e){}function e(){if(window.performance&&window.performance.getEntries)if(Array.prototype.indexOf&&Array.prototype.find&&Array.prototype.filter&&Array.prototype.map)if(Promise){var e=window.performance.getEntries().shift(),n={t0:i(e.startTime),t4:i(e.responseEnd),sz:i(e.transferSize),szb:i(e.encodedBodySize),p:s(e)},t=window.performance.getEntriesByType("resource").filter(function(e){switch(window.probSpeedHq.process_for||"all"){case"image":return/\.(jpg|jpeg|svg|gif|png|webp)$/.test(e.name);case"media":return/\.(jpg|gif|jpeg|png|mp4|ogg|mpeg|mov|mp3)$/.test(e.name);case"css":return/\.(css)$/.test(e.name);case"js":return/\.(js)$/.test(e.name);case"none":return!1;case"all":default:return!0}}).map(function(e){return{t0:i((e=e||{}).startTime),t4:i(e.responseEnd),sz:i(e.transferSize),szb:i(e.encodedBodySize),nhp:e.nextHopProtocol,u:e.name,p:s(e)}}),o={c:window.location.href,p:n,i:t,ua:navigator.userAgent},r=new XMLHttpRequest;r.open("POST","https://probe.speedhq.net/speed?xp=A&token=nicematin",!0),r.send(JSON.stringify(o))}else console.log("Promise is not define");else console.log("Missing function on Array");else console.log("No performance object found")}function s(e){return{dns:i(e.domainLookupEnd-e.domainLookupStart),con:i(e.connectEnd-e.connectStart),ssl:i(e.secureConnectionStart?e.connectEnd-e.secureConnectionStart:0),req:i(e.responseStart-e.requestStart),res:i(e.responseEnd-e.responseStart)}}function i(e){return+(e||0).toFixed(2)}}();
# </script>
# <script src="https://cdn.assets03.nicematin.com/build/js/freemium/article.85154b8b.js"></script>
# <script type="text/javascript">
#
#               (function() {
#
#                 /** CONFIGURATION END **/
#                 function loadChartbeat() {
#                     var e = document.createElement('script');
#                     var n = document.getElementsByTagName('script')[0];
#                     e.type = 'text/javascript';
#                     e.async = true;
#                     e.src = '//static.chartbeat.com/js/chartbeat.js';
#                     n.parentNode.insertBefore(e, n);
#                 }
#
#                 window.didomiOnReady = window.didomiOnReady || [];
#                 window.didomiOnReady.push(function (Didomi) {
#
#                     /** CONFIGURATION START **/
#                     var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});
#                                                                                             _sf_async_config.sections = 'education,faits-de-societe';
#                         _sf_async_config.authors = 'Nathan Beaufils';
#                                         var cbConsent = Didomi.getUserConsentStatus(Didomi.Purposes.Cookies, 'c:chartbeat');
#
#                     var _cbq = window._cbq = (window._cbq || []);
#
#                     if (cbConsent) {
#                         _sf_async_config.noCookies = !cbConsent;
#                         loadChartbeat();
#                     }
#
#                     Didomi.on('notice.clickagree', function() {
#                         _sf_async_config.noCookies = false;
#                         loadChartbeat();
#                     });
#
#                     Didomi.on('preferences.clickagreetoall', function() {
#                         _sf_async_config.noCookies = false;
#                         loadChartbeat();
#                     });
#
#                 });
#
#             })();
#
#         </script>
# <!-- Poool -->
# <script type="text/javascript">
#
#     window.pooolConfig = {
#     'id': 'oE6vNGIx3sxs5bfcJ46lDIYCfnOcKglv9hEje0n91UHMyEuB9crSmCPb2uBaSEig',
#     'debug': false,
#     'isLrr': false,
#     'outbrain': 'fac083a3',
#     'app_name': "Nice-Matin",
#     'login_url':  atob("aHR0cHM6Ly93d3cubmljZW1hdGluLmNvbS91c2VyL2xvZ2luP19yZWRpcmVjdF90YXJnZXRfcGF0aD1odHRwczovL3d3dy5uaWNlbWF0aW4uY29tL2EvOTI2NjE2"),
#     'short_article_url': atob("aHR0cHM6Ly93d3cubmljZW1hdGluLmNvbS9hLzkyNjYxNg=="),
#     'subscription_url': atob("").replace('__curent-url__', window.location.href),
#     'event': {},
#     'consent_wall': {
#               'enabled': true,
#         'consentUpdated': false,
#                   'for_free_article': true,
#                   },
#     'refusedCmp': false,
#     'user_role': "ROLE_ANONYMOUS",
#     'page_view': 'premium'
#   };
#
#   // PageType
#                         window.pooolConfig.event.page_view = "premium";
#
#   // Default Widget with ViewPay
#         window.pooolConfig.viewpay_id = '8ca0ef322722091b';
#
#   // When user has completed successfully the tunnel or instant payment purchase
#     </script>
# <style>
#   #poool-widget .p3-widget .p3-wrapper { top:20px !important; }
#   </style>
# <!-- END Poool -->
# <script async="" src="https://news.google.com/swg/js/v1/swg.js"></script>
# <script type="text/javascript">
#       window.NMArticleConfig.isNative = 'false';
#       window.NMArticleConfig.isPremium = 'true';
#       window.NMArticleConfig.articleId = '926616';
#     </script>
# <script>
#         if ((window.NMAuth && window.NMAuth.user.isConnected) || (window.pooolConfig && window.pooolConfig.event.page_view === "free")) {
#
#             let listContentSpacing = [...document.querySelectorAll(".article--content-spacing")]
#       let target = listContentSpacing.length > 0 ? listContentSpacing.pop().querySelector(':scope > :last-child') : null;
#
#             if (target !== null && target.previousElementSibling && target.previousElementSibling.nodeName.substring(0, 1) === 'H') {
#         target = target.previousElementSibling;
#       }
#
#             if (target !== null) {
#         const node = document.createElement('div');
#         node.className = 'logora_synthese';
#         node.setAttribute('data-object-id', 'logora_config');
#         target.insertAdjacentElement('beforebegin', node);
#       }
#     }
#   </script>
# <script>
# var logora_config = {
#     shortname: "nicematin-cd6b90",
#             debate: {
#             identifier: "926616"
#         },
#         remote_auth: '',
#     auth: {
#         login_url: 'https://www.nicematin.com/user/login',
#         redirectParameter: '_redirect_target_path'
#     }
# };
# </script>
# <script>
#     (function () {
#       var d = document, s = d.createElement('script');
#       s.src = 'https://api.logora.fr/synthese.js';
#       (d.head || d.body).appendChild(s);
#     })();
#   </script>
# <!-- Non.li -->
# <script type="text/javascript">
#         window._nli=window._nli||[],window._nli.push(["brand","BNLI-1409"]),function(){var n,e,i=window._nli||(window._nli=[]);i.loaded||((n=document.createElement("script")).defer=!0,n.src="https://l.nicematin.com/sdk.js",(e=document.getElementsByTagName("script")[0]).parentNode.insertBefore(n,e),i.loaded=!0)}();
#     </script>
# <!-- Non.li -->
# <div class="nm-cookies-wall nm-cookies-wall--section nm" id="nm-cookies-wall">
# <div class="nm-cookies-wall--grid">
# <div class="nm-cookies-wall--header">
# <img alt="Nice-Matin" class="nm-cookies-wall--logo_editeur" src="https://cdn.assets03.nicematin.com/build/imgs/titles/title_nm.8d47c419.svg">
# <div class="nm-cookies-wall--header--sub">
# <p class="nm-cookies-wall--title" id="nm-cookies-wall--title">Un cookie pour nous soutenir</p>
# <div class="hide-down-md" id="nm-cookies-wall--btn">
# <a class="nm-cookies-wall--btn--accept nm" href="#" id="nm-cookies-wall--btn--accept" onclick="Didomi.setUserAgreeToAll();" title="J'accepte les cookies">J'accepte les cookies</a>
# </div> </div>
# </img></div>
# <div class="nm-cookies-wall--message" id="nm-cookies-wall--message">
# <p>Nous avons besoin de vos cookies pour vous offrir une expérience de lecture optimale et vous proposer des publicités personnalisées.</p>
# <p>Accepter les cookies, c’est permettre grâce aux revenus complémentaires de soutenir le travail de nos 180 journalistes qui veillent au quotidien à vous offrir une information de qualité et diversifiée. Ainsi, vous pourrez accéder librement au site.</p>
# <p>Vous pouvez choisir de refuser les cookies en vous connectant ou en vous abonnant.</p>
# <div class="nm-cookies-wall--btn--group hide-down-md">
# <div class="nm-cookies-wall--btn--row">
# <div id="nm-cookies-wall--btn">
# <a class="nm-cookies-wall--btn--cta" href="https://abo.nicematin.com/cart/products/add?product_id=1055&amp;_redirect_target_path=https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616&amp;lastpage_abo=https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616&amp;lastclic_abo=Je%20m%27abonne&amp;lastclic_1er_niveau_abo=https://abo.nicematin.com/abonnement/formules&amp;lastclic_2e_niveau_abo=nm-cookies-wall" id="nm-cookies-wall--btn--cta" title="Je m'abonne">
#             Je m'abonne
#         </a>
# </div>
# <div class="hide-up-md" id="nm-cookies-wall--btn">
# <a class="nm-cookies-wall--btn--accept nm" href="#" id="nm-cookies-wall--btn--accept" onclick="Didomi.setUserAgreeToAll();" title="J'accepte les cookies">J'accepte les cookies</a>
# </div></div>
# <div class="nm-cookies-wall--btn--row">
# <div id="nm-cookies-wall--btn">
# <a class="nm-cookies-wall--btn--cta" href="https://www.nicematin.com/user/login?_redirect_target_path=https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616" id="nm-cookies-wall--btn--cta" rel="nofollow" title="Je me connecte/je crée un compte">
#             Je me connecte/je crée un compte
#         </a>
# </div>
# </div> </div>
# </div>
# <div class="nm-cookies-wall--footer">
# <p>Merci de la part de toute notre rédaction 🙏</p>
# </div>
# <div class="nm-cookies-wall--btn--group hide-up-md">
# <div class="nm-cookies-wall--btn--row">
# <div id="nm-cookies-wall--btn">
# <a class="nm-cookies-wall--btn--cta" href="https://abo.nicematin.com/cart/products/add?product_id=1055&amp;_redirect_target_path=https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616&amp;lastpage_abo=https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616&amp;lastclic_abo=Je%20m%27abonne&amp;lastclic_1er_niveau_abo=https://abo.nicematin.com/abonnement/formules&amp;lastclic_2e_niveau_abo=nm-cookies-wall" id="nm-cookies-wall--btn--cta" title="Je m'abonne">
#             Je m'abonne
#         </a>
# </div>
# <div class="hide-up-md" id="nm-cookies-wall--btn">
# <a class="nm-cookies-wall--btn--accept nm" href="#" id="nm-cookies-wall--btn--accept" onclick="Didomi.setUserAgreeToAll();" title="J'accepte les cookies">J'accepte les cookies</a>
# </div></div>
# <div class="nm-cookies-wall--btn--row">
# <div id="nm-cookies-wall--btn">
# <a class="nm-cookies-wall--btn--cta" href="https://www.nicematin.com/user/login?_redirect_target_path=https://www.nicematin.com/education/on-fait-ce-stage-par-depit-clairement-926616" id="nm-cookies-wall--btn--cta" rel="nofollow" title="Je me connecte/je crée un compte">
#             Je me connecte/je crée un compte
#         </a>
# </div>
# </div> </div>
# </div>
# </div>
# </body>
# </html>

# %%
title = soup.find('h1', attrs = {'class':"article-title"}).text
title
# Out:
# '"On le fait par dépit, clairement": la galère des lycéens de seconde à Antibes pour trouver un stage de fin d\'année'

# %%
excerpt = soup.find('h2', attrs = {'class':"article-excerpt"}).text.strip('\r\n ')
excerpt
# Out:
# 'Pour la première fois, les élèves de seconde devront faire un stage. Certains essuient des refus et se rabattent sur des secteurs qui ne sont pas en lien avec leurs études.'

# %%
author = soup.find('span', attrs = {'class':"author"})
if author: author = author.text
author
# Out:
# 'Nathan Beaufils'

# %%
published = soup.find('span', attrs = {'class':"published-at"})
if published: published = published.text
published
# Out:
# 'Publié le 10/06/2024 à 08:45, mis à jour le 10/06/2024 à 08:45'

# %%
city = soup.find('a', attrs = {'class':"blue city"})
if city: city = city.text
city
# Out:
# 'Antibes'

# %%
full_text = soup.find('section', attrs = {'class':"article-block", 'id':'full-text'})
if full_text: full_text = full_text.text.strip('\ncommentaires ')
full_text
# Out:
# 'Devant le lycée Jacques-Audiberti, les élèves sortent les uns après les autres. C’est la récréation, l’une des dernières avant la fin de l’année.\nPour les classes de seconde générale et technologique, la fin de l’année ne se déroulera pas au lycée, mais en milieu professionnel, pour un stage de deux semaines, du 17 au 28 juin. Une nouvelle mesure prise à la rentrée par Gabriel Attal.\n"Essaie de faire ce choix en lien avec ton projet d’études", s’adressait aux lycéens l’ancien ministre de l’Éducation nationale sur son compte TikTok en novembre dernier.\nDes élèves sans stage \nPour ces jeunes étudiants, trouver un stage qui leur plaît n’est pas une mince affaire. "J’ai demandé dans des magasins, mais ils ne prennent pas à notre âge (15 ans, Ndlr). J’ai donc fait appel à ma mère pour travailler avec elle dans une entreprise de nettoyage", regrette Alexia.\nSon amie Manon a aussi essuyé plusieurs refus de la part de boutiques de produits de beauté.\xa0"On fait ce stage par dépit, clairement", concluent-elles.\nCertains n’ont toujours pas trouvé, à moins de deux semaines du début. Oswa veut aussi découvrir le monde du commerce, mais a eu cinq réponses négatives.\n"Énormément d’élèves cherchent un stage en même temps, en plus des filières professionnelles, explique-t-elle. Pour trouver des stages c’est très compliqué et décourageant."\nQuant aux enseignants, ils considèrent que l’initiative ne laisse pas les élèves avec trois mois de vacances.\xa0"Qu’on leur ait imposé ce stage va leur permettre de ne pas errer et de ne pas rien faire", s’enthousiasme Nora Choubane, professeure principale d’une classe de seconde au lycée Jacques-Audiberti.\nL’enseignante accompagne ses élèves dans leur recherche.\xa0"Sur 33, ils sont 4 à ne pas avoir de stage. Je les encourage à faire du porte-à-porte pour en trouver un coûte que coûte."\xa0\nSelon elle, si certains ne savent pas où ils seront le 17 juin, c’est plus "par paresse"\xa0que par manque d’offres.\nAmis et famille sont contactés \nAu lycée Leonard-de-Vinci, dans la classe d’Alice Di Lenarda, tous les élèves ont trouvé leur stage.\nLa très grande majorité a fait marcher leur (petit) carnet d’adresses pour pouvoir être en entreprise le 17 juin. Parents, oncles, tantes ou encore amis ont aidé à la recherche de stage.\nLa professeure de SVT est aussi élogieuse à propos de cette nouvelle mesure: "Cela leur permet de rentrer pour la première fois ou presque dans le monde du travail. Après c’est toujours pareil, les plus sérieux trouvent en premier, les autres ensuite."\nLes élèves ont encore 10 jours pour trouver, sinon, ils seront accueillis par leur lycée durant ces deux semaines.'

# %% [markdown]
# Напишем функцию, возвращающую информацию из новости (title, author, published, region, excerpt, full_text) по url

# %%
def getNewsData (nlink):
    
    response = requests.get(nlink, headers={'User-Agent': UserAgent().chrome})
    html = response.content
    soup = BeautifulSoup(html, 'html.parser')

    title = soup.find('h1', attrs = {'class':"article-title"})
    if title: title = title.text

    author = soup.find('span', attrs = {'class':"author"})
    if author: author = author.text
    
    published = soup.find('span', attrs = {'class':"published-at"})
    if published: published = published.text

    city = soup.find('a', attrs = {'class':"blue city"})
    if city: city = city.text
    
    excerpt = soup.find('h2', attrs = {'class':"article-excerpt"})
    if excerpt: excerpt = excerpt.text.strip('\r\n ')

    full_text = soup.find('section', attrs = {'class':"article-block", 'id':'full-text'})
    if full_text: full_text = full_text.text.strip('\ncommentaires ')

    data_row = {'Title':title, 'Author':author, 'Published':published, 'Region':city,
                'Excerpt':excerpt, 'Full_text':full_text}   
    
    return data_row

# %%
allnews_links_list[13]
# Out:
# 'https://www.nicematin.com/faits-de-societe/et-si-cette-drole-de-maison-en-forme-de-a-etait-lavenir-de-la-construction-925416'

# %%
data_row = getNewsData(allnews_links_list[13])

# %%
data_row
# Out:
# {'Title': "Et si cette drôle de maison en forme de A était l'avenir de la construction?",
#  'Author': 'Emma Gouaille - Sud Ouest',
#  'Published': 'Publié le 07/06/2024 à 18:45, mis à jour le 07/06/2024 à 18:45',
#  'Region': 'France',
’autres auto-constructeurs de la communauté, espère avoir fini d’ici un an et demi.\nUn habitat écolo\nFlorian et Gilliane se sont d’abord essayé à la "tiny house", autre habitat atypique. Cette "maison minuscule" (littéralement) est généralement construite en bois et conçue pour être déplacée sur remorque. Une première étape avant leur maison en A. "On a vu comment construire une maison ossature bois et on a déjà les outils, donc si on suit le même modèle qu’Elizabeth, ça devrait aller."\nPour réaliser leur projet, ces Bordelais ont dû migrer en Dordogne. C’est à Eygurande-et-Gardedeuil qu\'ils ont trouvé le terrain de leurs rêves et obtenu un permis de construire. Échaudés par des expériences passées, ils souhaitaient être autonomes et ne pas contracter d’emprunt. Sur leur terrain de 6 000 m², ils rêvent d’une vie plus proche de la nature.\nElizabeth Faure se réjou ...

# %% [markdown]
# Работает ! Осталось пройти в цикле по всем новостным ссылкам и сохранить полученные данные в pandas dataframe

# %%
df_news = pd.DataFrame(columns=['Title', 'Author', 'Published', 'Region','Excerpt', 'Full_text'])

# %%
for news_link in tqdm(allnews_links_list):
    data_row = getNewsData(news_link)
    df_news = pd.concat([df_news, pd.DataFrame([data_row])], ignore_index=True)
    time.sleep(0.3)
# Out:
# 100%|█████████████████████████████████████████| 294/294 [04:40<00:00,  1.05it/s]

# %%
df_news.shape
# Out:
# (294, 6)

# %%
df_news.tail()
# Out:
#                                                  Title  \
# 289  Une brebis dévorée et deux autres blessées à S...
# 290  Face au changement climatique, deux modes d'em...
# 291  Un nouveau rond-point inauguré dans l’arrière-...
# 292                 TAMA, 60 ans de travaux en famille
# 293  400 élèves, un établissement à "taille humaine...
#
#                                       Author  \
# 289                          Mathilde Tranoy
# 290      Aurélie Selvi - aselvi@nicematin.fr
# 291  Benoit Guglielmibguglielmi@nicematin.fr
# 292                                 K.Wenger
# 293                                    E. G.
#
#                                              Published   Region  \
# 289  Publié le 08/06/2024 à 19:45, mis à jour le 08...  Vallées
# 290  Publié le 08/06/2024 à 09:45, mis à jour le 08...    Vence
# 291  Publié le 08/06/2024 à 07:52, mis à jour le 08...  Vallées
# 292  Publié le 07/06/2024 à 14:44, mis à jour le 07...     Nice
# 293  Publié le 07/06/2024 à 10:53, mis à jour le 07...  Vallées
#
#                                                Excerpt  \
# 289  Une brebis a été retrouvée morte et deux autre...
# 290  Face au changement climatique, comment trouver...
# 291  Le giratoire Charles-Ginésy doit être inauguré...
# 292  L’entreprise de travaux publics cagnoise TAMA,...
# 293  Le conseil départemental des Alpes-Maritimes a...
#
#                                              Full_text
# 289  Macabre découverte ce samedi matin à Saint-Eti...
# 290  En France, de 2010 à 2020, une surface équival...
# 291  Plus de sécurité: voilà ce qu’est censé apport...
# 292  Juin 1964. Antoine Renaudi, 28 ans, possède un...
# 293  Le collège Roger-Carlès de Contes, prévu pour ...

# %% [markdown]
# ### Вывод
# Получилось собрать данные с новостного сайта Nice-Matin, но поскольку датасет получился небольшим и в нем не оказалось целевой переменной ), то для второй части использую датасет IMDB. И спасибо за задание - его выполнение доставило мне искреннее удовольствие, словно бродил не по сайту, а по улицам Ниццы...
