# %% [markdown]
# # Сравнение алгоритмов градиентного бустинга или в живых останется только один...

# %% [markdown]
# <img src="img/gb-img-04.jpg" style="width:384px;height:384px;">

# %% [markdown]
# Загружаем необходимые библиотеки

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.ticker as mtick # For specifying the axes tick format 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Проводить сравнение алгоритмов бустинга мы будем на наборе данных для классификации, а именно, предсказания оттока клиентов телеком оператора https://www.kaggle.com/datasets/blastchar/telco-customer-churn

# %%
df = pd.read_csv('data/WA_Fn-UseC_-Telco-Customer-Churn.csv', index_col=0)

# %%
df.head()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %% [markdown]
# <details>
#     <summary>Spoiler name</summary>
#     <pre><code lang="python">
#     import numpy as np
#     YOUR CODE
#     a,b = 3,5
#     a + b =
#     </code></pre>
# </details>

# %% [markdown]
# <details>
# 	<summary>spoiler alert: a table</summary>
#
# | a   | b   | c   |
# | --- | --- | --- |
# | 1   | 2   | 3   |
# </details>
#
# <details>
# 	<summary>aligned columns in a table</summary>
#
# | a   | b   | c   |
# | :--- | :---: | ---: |
# | 1   | 2   | 3   |
# </details>

# %% [markdown]
# <details>
#   <summary>Screenshot under spoiler</summary>
#   <img src="img/WP-banana-auction.png" style="width:440px;height:292px;">
# </details>

# %% [markdown]
# Just an image after some text
#
# <img src="img/WP-banana-auction.png" style="width:440px;height:292px;">

# %% [markdown]
# markdown
# | Header 1 | Header 2 | Header 3 |
# |----------|----------|----------|
# | Row 1    | Data 1   | Data 2   |
# | Row 2    | Data 3   | Data 4   |
# | Row 3    | Data 5   | Data 6   |

# %% [markdown]
# <div align='left'>
# # <div style="margin-left: 0;
# #            margin-right: auto;
# #            width: 30%">
# markdown
# | Header 1 | Header 2 | Header 3 |
# |:--------- |:---------: |---------:|
# | Row 1    | Data 1   | Data 2   |
# | Row 2    | Data 3   | Data 4   |
# | Row 3    | Data 5   | Data 6   |
# </div>

# %% [markdown]
# html
#    <style>
#    table {
#        margin-left: 0; /* Aligns the table to the left */
#    }
#    | Header 1 | Header 2 | Header 3 |
#    |----------|----------|----------|
#    | Row 1    | Data 1   | Data 2   |
#    | Row 2    | Data 3   | Data 4   |
#    | Row 3    | Data 5   | Data 6   |
#    </style>
