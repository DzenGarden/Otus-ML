# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, ElasticNetCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from category_encoders import OneHotEncoder, OrdinalEncoder, CountEncoder

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

from scipy import stats

# from sklearn.model_selection import cross_val_score

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Часть 1. EDA
#
# #### 1.1 Скачайте данные с Kaggle по ценам на жильё в Airbnb в Нью-Йорке:
# https://www.kaggle.com/dgomonov/new-york-city-airbnb-open-data

# %%
df = pd.read_csv('data/AB_NYC_2019.csv', index_col=0)

# %%
df.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington   40.6475   -73.9724     Private room
# 2595           Manhattan       Midtown   40.7536   -73.9838  Entire home/apt
# 3647           Manhattan        Harlem   40.8090   -73.9419     Private room
# 3831            Brooklyn  Clinton Hill   40.6851   -73.9598  Entire home/apt
# 5022           Manhattan   East Harlem   40.7985   -73.9440  Entire home/apt
#
#       price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# id
# 2539    149               1                  9  2018-10-19             0.2100
# 2595    225               1                 45  2019-05-21             0.3800
# 3647    150               3                  0         NaN                NaN
# 3831     89               1                270  2019-07-05             4.6400
# 5022     80              10                  9  2018-11-19             0.1000
#
#       calculated_host_listings_count  availability_365
# id
# 2539                               6               365
# 2595                               2               355
# 3647                               1               365
# 3831                               1               194
# 5022                               1                 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48895 entries, 2539 to 36487245
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            48879 non-null  object
#  1   host_id                         48895 non-null  int64
#  2   host_name                       48874 non-null  object
#  3   neighbourhood_group             48895 non-null  object
#  4   neighbourhood                   48895 non-null  object
#  5   latitude                        48895 non-null  float64
#  6   longitude                       48895 non-null  float64
#  7   room_type                       48895 non-null  object
#  8   price                           48895 non-null  int64
#  9   minimum_nights                  48895 non-null  int64
#  10  number_of_reviews               48895 non-null  int64
#  11  last_review                     38843 non-null  object
#  12  reviews_per_month               38843 non-null  float64
#  13  calculated_host_listings_count  48895 non-null  int64
#  14  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(6), object(6)
# memory usage: 6.0+ MB

# %%
df.describe()
# Out:
#                host_id    latitude   longitude       price  minimum_nights  \
# count      48,895.0000 48,895.0000 48,895.0000 48,895.0000     48,895.0000
# mean   67,620,010.6466     40.7289    -73.9522    152.7207          7.0300
# std    78,610,967.0327      0.0545      0.0462    240.1542         20.5105
# min         2,438.0000     40.4998    -74.2444      0.0000          1.0000
# 25%     7,822,033.0000     40.6901    -73.9831     69.0000          1.0000
# 50%    30,793,816.0000     40.7231    -73.9557    106.0000          3.0000
# 75%   107,434,423.0000     40.7631    -73.9363    175.0000          5.0000
# max   274,321,313.0000     40.9131    -73.7130 10,000.0000      1,250.0000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count        48,895.0000        38,843.0000                     48,895.0000
# mean             23.2745             1.3732                          7.1440
# std              44.5506             1.6804                         32.9525
# min               0.0000             0.0100                          1.0000
# 25%               1.0000             0.1900                          1.0000
# 50%               5.0000             0.7200                          1.0000
# 75%              24.0000             2.0200                          2.0000
# max             629.0000            58.5000                        327.0000
#
#        availability_365
# count       48,895.0000
# mean           112.7813
# std            131.6223
# min              0.0000
# 25%              0.0000
# 50%             45.0000
# 75%            227.0000
# max            365.0000

# %% [markdown]
# ### 1.2 Пройдите по основным шагам работы с данными:
#
# #### 1.2.1 Выкиньте ненужные признаки: id, name, host_id, host_name, last_review
# - визуализируйте базовые статистики данных: распределения признаков, матрицу попарных корреляций, постройте pair plots
# - по результатам анализа произведите предобработку переменных

# %%
df = df.drop(['name', 'host_id', 'host_name', 'last_review'], axis=1)

# %% [markdown]
# #### 1.2.2 Визуализируйте базовые статистики данных: распределения признаков, матрицу попарных корреляций, постройте pair plots

# %% [markdown]
# Начнем с числовых признаков

# %%
df.hist(figsize=(20,12));

# %% [markdown]
# Распределения числовых признаков, и в частности, цены, сильно сдвинуты влево, что говорит о наличии выбросов. Помимо числовых признаков, в наборе есть три категориальных - посмотрим на них более детально

# %%
df.describe(include='object')
# Out:
#        neighbourhood_group neighbourhood        room_type
# count                48895         48895            48895
# unique                   5           221                3
# top              Manhattan  Williamsburg  Entire home/apt
# freq                 21661          3920            25409

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['neighbourhood_group', 'neighbourhood', 'room_type'], dtype='object')

# %%
df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
df['room_type'].hist()
# Out:
# <Axes: >

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df['neighbourhood_group'].hist()
# Out:
# <Axes: >

# %%
df['neighbourhood'].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
#        'Greenwich Village', 'Little Italy', 'East Flatbush',
#        'Tompkinsville', 'Astoria', 'Clason Point', 'Eastchester',
#        'Kingsbridge', 'Two Bridges', 'Queens Village', 'Rockaway Beach',
#        'Forest Hills', 'Nolita', 'Woodlawn', 'University Heights',
#        'Gravesend', 'Gramercy', 'Allerton', 'East New York',
#        'Theater District', 'Concourse Village', 'Sheepshead Bay',
#        'Emerson Hill', 'Fort Hamilton', 'Bensonhurst', 'Tribeca',
#        'Shore Acres', 'Sunset Park', 'Concourse', 'Elmhurst',
#        'Brighton Beach', 'Jackson Heights', 'Cypress Hills', 'St. Albans',
#        'Arrochar', 'Rego Park', 'Wakefield', 'Clifton', 'Bay Ridge',
#        'Graniteville', 'Spuyten Duyvil', 'Stapleton', 'Briarwood',
#        'Ozone Park', 'Columbia St', 'Vinegar Hill', 'Mott Haven',
#        'Longwood', 'Canarsie', 'Battery Park City', 'Civic Center',
#        'East Elmhurst', 'New Springville', 'Morris Heights', 'Arverne',
#        'Cambria Heights', 'Tottenville', 'Mariners Harbor', 'Concord',
#        'Borough Park', 'Bayside', 'Downtown Brooklyn', 'Port Morris',
#        'Fieldston', 'Kew Gardens', 'Midwood', 'College Point',
#        'Mount Eden', 'City Island', 'Glendale', 'Port Richmond',
#        'Red Hook', 'Richmond Hill', 'Bellerose', 'Maspeth',
#        'Williamsbridge', 'Soundview', 'Woodhaven', 'Woodrow',
#        'Co-op City', 'Stuyvesant Town', 'Parkchester', 'North Riverdale',
#        'Dyker Heights', 'Bronxdale', 'Sea Gate', 'Riverdale',
#        'Kew Gardens Hills', 'Bay Terrace', 'Norwood', 'Claremont Village',
#        'Whitestone', 'Fordham', 'Bayswater', 'Navy Yard', 'Brownsville',
#        'Eltingville', 'Fresh Meadows', 'Mount Hope', 'Lighthouse Hill',
#        'Springfield Gardens', 'Howard Beach', 'Belle Harbor',
#        'Jamaica Estates', 'Van Nest', 'Morris Park', 'West Brighton',
#        'Far Rockaway', 'South Ozone Park', 'Tremont', 'Corona',
#        'Great Kills', 'Manhattan Beach', 'Marble Hill', 'Dongan Hills',
#        'Castleton Corners', 'East Morrisania', 'Hunts Point', 'Neponsit',
#        'Pelham Bay', 'Randall Manor', 'Throgs Neck', 'Todt Hill',
#        'West Farms', 'Silver Lake', 'Morrisania', 'Laurelton',
#        'Grymes Hill', 'Holliswood', 'Pelham Gardens', 'Belmont',
#        'Rosedale', 'Edgemere', 'New Brighton', 'Midland Beach',
#        'Baychester', 'Melrose', 'Bergen Beach', 'Richmondtown',
#        'Howland Hook', 'Schuylerville', 'Coney Island', 'New Dorp Beach',
#        "Prince's Bay", 'South Beach', 'Bath Beach', 'Jamaica Hills',
#        'Oakwood', 'Castle Hill', 'Hollis', 'Douglaston', 'Huguenot',
#        'Olinville', 'Edenwald', 'Grant City', 'Westerleigh',
#        'Bay Terrace, Staten Island', 'Westchester Square', 'Little Neck',
#        'Fort Wadsworth', 'Rosebank', 'Unionport', 'Mill Basin',
#        'Arden Heights', "Bull's Head", 'New Dorp', 'Rossville',
#        'Breezy Point', 'Willowbrook'], dtype=object)

# %%
df_gb_nbrh = df.groupby(['neighbourhood'])['neighbourhood'].count()

# %%
df_gb_nbrh.sort_values(ascending=False).head(10)
# Out:
# neighbourhood
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# Name: neighbourhood, dtype: int64

# %%
df_gb_nbrh.sort_values(ascending=True).plot.barh(figsize=(15,42));

# %%
df[['room_type','neighbourhood_group','neighbourhood']].nunique()
# Out:
# room_type                3
# neighbourhood_group      5
# neighbourhood          221
# dtype: int64

# %% [markdown]
# Посмотрим на зависимость цены от типа комнаты и местоположения

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x="room_type", y="price",
            hue="neighbourhood_group", size="neighbourhood_group",
            sizes=(50, 200), palette="Dark2", data=df)

plt.xlabel("Room Type", size=13)
plt.ylabel("Price", size=13)
plt.title("Room Type vs Price vs Neighbourhood Group",size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Room Type vs Price vs Neighbourhood Group')

# %% [markdown]
# Стоимость shared room не поднимается выше 2000, при этом самая высокая стоимость аренды, ожидаемо, на Манхэттене, следом за ним идет Бруклин

# %%
plt.figure(figsize=(15,10))
#sns.displot(data=df, x='price', kde=True)
sns.histplot(data=df, x='price', kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
df.price.describe()
# Out:
# count   48,895.0000
# mean       152.7207
# std        240.1542
# min          0.0000
# 25%         69.0000
# 50%        106.0000
# 75%        175.0000
# max     10,000.0000
# Name: price, dtype: float64

# %% [markdown]
# Построим boxplot

# %%
fig = plt.figure(figsize =(15, 4))
 
plt.boxplot(df['price'], vert=0)
plt.show()

# %%
IQR = df['price'].quantile(q=0.75) - df['price'].quantile(q=0.25)

# %%
IQR
# Out:
# 106.0

# %%
r_bound = df['price'].quantile(q=0.75) + 1.5*IQR

# %%
r_bound
# Out:
# 334.0

# %% [markdown]
# Для построения матрицы корреляций сделаем быстрый маппинг категориальных признаков с использованием cat.codes

# %%
data_nyc = df.copy()

# %%
data_nyc['neighbourhood_group']= data_nyc['neighbourhood_group'].astype("category").cat.codes
data_nyc['neighbourhood'] = data_nyc['neighbourhood'].astype("category").cat.codes
data_nyc['room_type'] = data_nyc['room_type'].astype("category").cat.codes

# %%
data_nyc.head()
# Out:
#       neighbourhood_group  neighbourhood  latitude  longitude  room_type  \
# id
# 2539                    1            108   40.6475   -73.9724          1
# 2595                    2            127   40.7536   -73.9838          0
# 3647                    2             94   40.8090   -73.9419          1
# 3831                    1             41   40.6851   -73.9598          0
# 5022                    2             61   40.7985   -73.9440          0
#
#       price  minimum_nights  number_of_reviews  reviews_per_month  \
# id
# 2539    149               1                  9             0.2100
# 2595    225               1                 45             0.3800
# 3647    150               3                  0                NaN
# 3831     89               1                270             4.6400
# 5022     80              10                  9             0.1000
#
#       calculated_host_listings_count  availability_365
# id
# 2539                               6               365
# 2595                               2               355
# 3647                               1               365
# 3831                               1               194
# 5022                               1                 0

# %%
fig, ax = plt.subplots(figsize=(10, 3))
sns.heatmap(data_nyc.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax);

# %% [markdown]
# Видим, что зависимость между признаками и ценой низкая - для модели будем использовать все атрибуты

# %% [markdown]
# включить перед отправкой

# %%
sns.pairplot(data=df, hue='price')
plt.show;

# %% [markdown]
# #### 1.2.3 По результатам анализа произведите предобработку переменных

# %% [markdown]
# Признак review_per_month имеет null-значения

# %%
df.isnull().sum()
# Out:
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# Посмотрим на пропущенные значения

# %%
df[df['reviews_per_month'].isna() == True]
# df[pd.isnull(df.reviews_per_month)]
# Out:
#          neighbourhood_group       neighbourhood  latitude  longitude  \
# id
# 3647               Manhattan              Harlem   40.8090   -73.9419
# 7750               Manhattan         East Harlem   40.7968   -73.9487
# 8700               Manhattan              Inwood   40.8675   -73.9264
# 11452               Brooklyn  Bedford-Stuyvesant   40.6888   -73.9431
# 11943               Brooklyn            Flatbush   40.6370   -73.9633
# ...                      ...                 ...       ...        ...
# 36484665            Brooklyn  Bedford-Stuyvesant   40.6785   -73.9500
# 36485057            Brooklyn            Bushwick   40.7018   -73.9332
# 36485431           Manhattan              Harlem   40.8147   -73.9487
# 36485609           Manhattan      Hell's Kitchen   40.7575   -73.9911
# 36487245           Manhattan      Hell's Kitchen   40.7640   -73.9893
#
#                 room_type  price  minimum_nights  number_of_reviews  \
# id
# 3647         Private room    150               3                  0
# 7750      Entire home/apt    190               7                  0
# 8700         Private room     80               4                  0
# 11452        Private room     35              60                  0
# 11943        Private room    150               1                  0
# ...                   ...    ...             ...                ...
# 36484665     Private room     70               2                  0
# 36485057     Private room     40               4                  0
# 36485431  Entire home/apt    115              10                  0
# 36485609      Shared room     55               1                  0
# 36487245     Private room     90               7                  0
#
#           reviews_per_month  calculated_host_listings_count  availability_365
# id
# 3647                    NaN                               1               365
# 7750                    NaN                               2               249
# 8700                    NaN                               1                 0
# 11452                   NaN                               1               365
# 11943                   NaN                               1               365
# ...                     ...                             ...               ...
# 36484665                NaN                               2                 9
# 36485057                NaN                               2                36
# 36485431                NaN                               1                27
# 36485609                NaN                               6                 2
# 36487245                NaN                               1                23
#
# [10052 rows x 11 columns]

# %% [markdown]
# Видим, что признак review_per_month не заполнен там, где number_of_reviews=0. Соответственно, для дальнейшей работы, заменим null-значения признака review_per_month на 0.

# %%
df['reviews_per_month'] = df['reviews_per_month'].fillna(0)

# %%
df.isna().sum()
# Out:
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# Как мы ранее видели, распределение цены сильно сдвинуто влево и линейная модель плохо подходит для предсказания таких данных

# %%
plt.figure(figsize=(7,7))
stats.probplot(df['price'], plot=plt)
plt.show()

# %% [markdown]
# Поэтому, проведем логарифмическое преобразование для "нормализации" распределения целевой переменной

# %%
df['price_log'] = np.log(df.price+1)

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df, x='price_log', kde=True)
# Out:
# <Axes: xlabel='price_log', ylabel='Count'>

# %%
plt.figure(figsize=(10,5))
stats.probplot(df['price_log'], plot=plt)
plt.show()

# %% [raw]
# Похоже, что такое распределение линейная модель сможет предсказать гораздо лучше - но мы это в любом случае проверим )

# %% [markdown]
# ## Часть 2. Preprocessing & Feature Engineering
# Ваша цель получить как можно более высокие метрики качества (можно взять несколько, R2, MAE, RMSE), сконцентрировавшись на преобразовании признаков.
# Опробуйте различные техники:
# - работа с категориальными переменными (можно начать с dummy);
# - замена аномалий;
# - различные варианты шкалирования непрерывных переменных (StandardScaler, RobustScaler, и.т.д.);
# - обратите внимание на распределение целевой переменной, возможно, с ней тоже можно поработать;
#
# Попробуйте на основании имеющихся переменных создать новые, которые могли бы улучшить качество модели. Например, можно найти координаты Манхэттена (самого дорогого района) и при помощи широты и долготы, а также евклидового расстояния создать новую переменную - расстояние от квартиры до этого района. Возможно, такой признак будет работать лучше, чем просто широта и долгота.

# %% [markdown]
# Опробуйте различные техники:
# - работа с категориальными переменными (можно начать с dummy);

# %% [markdown]
# Определим функцию кодировки категориальных признаков выбранным методом

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['neighbourhood_group', 'neighbourhood', 'room_type'], dtype='object')

# %%
def onehot_encode_func(data, cols = ['neighbourhood_group', 'neighbourhood', 'room_type']):
    data_enc = data.copy()
    data_enc = pd.get_dummies(data_enc, columns=cols, dtype=float)
    return data_enc

# %%
def count_encode_func(data, cols = ['neighbourhood_group', 'neighbourhood', 'room_type']):
    enc = CountEncoder()
    data_enc = data.copy()
    data_enc[cols]= enc.fit_transform(data_enc[cols])
    return data_enc

# %%
df_ce = count_encode_func(df)

# %%
df_ce
# Out:
#           neighbourhood_group  neighbourhood  latitude  longitude  room_type  \
# id
# 2539                    20104            175   40.6475   -73.9724      22326
# 2595                    21661           1545   40.7536   -73.9838      25409
# 3647                    21661           2658   40.8090   -73.9419      22326
# 3831                    20104            572   40.6851   -73.9598      25409
# 5022                    21661           1117   40.7985   -73.9440      25409
# ...                       ...            ...       ...        ...        ...
# 36484665                20104           3714   40.6785   -73.9500      22326
# 36485057                20104           2465   40.7018   -73.9332      22326
# 36485431                21661           2658   40.8147   -73.9487      25409
# 36485609                21661           1958   40.7575   -73.9911       1160
# 36487245                21661           1958   40.7640   -73.9893      22326
#
#           price  minimum_nights  number_of_reviews  reviews_per_month  \
# id
# 2539        149               1                  9             0.2100
# 2595        225               1                 45             0.3800
# 3647        150               3                  0             0.0000
# 3831         89               1                270             4.6400
# 5022         80              10                  9             0.1000
# ...         ...             ...                ...                ...
# 36484665     70               2                  0             0.0000
# 36485057     40               4                  0             0.0000
# 36485431    115              10                  0             0.0000
# 36485609     55               1                  0             0.0000
# 36487245     90               7                  0             0.0000
#
#           calculated_host_listings_count  availability_365  price_log
# id
# 2539                                   6               365     5.0106
# 2595                                   2               355     5.4205
# 3647                                   1               365     5.0173
# 3831                                   1               194     4.4998
# 5022                                   1                 0     4.3944
# ...                                  ...               ...        ...
# 36484665                               2                 9     4.2627
# 36485057                               2                36     3.7136
# 36485431                               1                27     4.7536
# 36485609                               6                 2     4.0254
# 36487245                               1                23     4.5109
#
# [48895 rows x 12 columns]

# %%
df_ohe = onehot_encode_func(df)

# %%
df_ohe.shape
# Out:
# (48895, 238)

# %%
df_ohe.columns
# Out:
# Index(['latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'price_log', 'neighbourhood_group_Bronx',
#        ...
#        'neighbourhood_Williamsburg', 'neighbourhood_Willowbrook',
#        'neighbourhood_Windsor Terrace', 'neighbourhood_Woodhaven',
#        'neighbourhood_Woodlawn', 'neighbourhood_Woodrow',
#        'neighbourhood_Woodside', 'room_type_Entire home/apt',
#        'room_type_Private room', 'room_type_Shared room'],
#       dtype='object', length=238)

# %% [markdown]
# ## Часть 3. Моделирование
#
# 1. Отложите 30% данных для тестирования.
# 2. Постройте модели простой линейной регрессии, RidgeCV, LassoCV и ElasticNetCV.
# 3. Измерьте качество каждой и визуализируйте важность признаков.
# 4. Сделайте интересные выводы :)
# 5. В ноутбуке желательно видеть:
#
# - Понятное описание: какие техники и алгоритмы были опробованы - было бы неплохо в самом начале тезисно выписать опробованные методики и их результат (помогло / не помогло).
# - Наличие визуализаций (не обязательно строить много графиков - можно несколько репрезентативных).
# - Наличие хотя бы одной модификации данных, приводящей к улучшению результатов.

# %% [markdown]
# 1. Отложите 30% данных для тестирования.

# %% [markdown]
# - df_ce - Count encoded dataset
# - df_ohe - OneHot encoded dataset

# %% [markdown]
# 2. Постройте модели простой линейной регрессии, RidgeCV, LassoCV и ElasticNetCV.

# %% [markdown]
# Создадим функцию оценки качества модели

# %%
def evaluate_model(data_enc, model, scaler, tv='price'):
    X_train, X_test, y_train, y_test = train_test_split(data_enc.drop(['price', 'price_log'], axis=1), \
                                                        data_enc[tv], test_size=0.3, random_state=13)
    X_train = std_scaler.fit_transform(X_train)
    X_test = std_scaler.transform(X_test)

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
  
    mae = round(mean_absolute_error(y_test, y_pred),4)
    mae_norm = round(mean_absolute_error(y_test, y_pred)/np.mean(y_test), 4)
    mse = round(mean_squared_error(y_test, y_pred), 4)
    R2 = round(r2_score(y_test, y_pred), 4)
    
#    print('MAE: ', round(mae,4))
#    print('MAE norm: ', round(mae_norm,4))
#    print('MSE: ', round(mse,4))
#    print('R2: ', round(R2,4))

    return [round(mae,4), round(mae_norm,4), round(mse,4), round(R2,4)]

# %%
results = {}

# %%
lr = LinearRegression()
lasso = LassoCV()
ridge = RidgeCV()
elastic = ElasticNetCV()

# %%
std_scaler = StandardScaler()
robust_scaler = RobustScaler()

# %% [markdown]
# ## Count Encoding - Standard Scaler

# %%
results['Count encoding - Linear - Standard Scaler'] = evaluate_model(df_ce, lr, std_scaler, tv='price')

# %%
results['Count encoding - Lasso - Standard Scaler'] = evaluate_model(df_ce, lasso, std_scaler, tv='price')

# %%
results['Count encoding - Ridge - Standard Scaler'] = evaluate_model(df_ce, ridge, std_scaler, tv='price')

# %%
results['Count encoding - Elastic - Standard Scaler'] = evaluate_model(df_ce, elastic, std_scaler, tv='price')

# %% [markdown]
# ## Count Encoding - Robust Scaler

# %%
results['Count encoding - Linear - Robust Scaler'] = evaluate_model(df_ce, lr, robust_scaler, tv='price')
results['Count encoding - Lasso - Robust Scaler'] = evaluate_model(df_ce, lasso, robust_scaler, tv='price')
results['Count encoding - Ridge - Robust Scaler'] = evaluate_model(df_ce, ridge, robust_scaler, tv='price')
results['Count encoding - Elastic - Robust Scaler'] = evaluate_model(df_ce, elastic, robust_scaler, tv='price')

# %% [markdown]
# ## OneHot Encoding - Standard Scaler

# %%
results['OneHot encoding - Linear - Standard Scaler'] = evaluate_model(df_ohe, lr, std_scaler, tv='price')
results['OneHot encoding - Lasso - Standard Scaler'] = evaluate_model(df_ohe, lasso, std_scaler, tv='price')
results['OneHot encoding - Ridge - Standard Scaler'] = evaluate_model(df_ohe, ridge, std_scaler, tv='price')
results['OneHot encoding - Elastic - Standard Scaler'] = evaluate_model(df_ohe, elastic, std_scaler, tv='price')

# %% [markdown]
# ## OneHot Encoding - Robust Scaler

# %%
results['OneHot encoding - Linear - Robust Scaler'] = evaluate_model(df_ohe, lr, robust_scaler, tv='price')
results['OneHot encoding - Lasso - Robust Scaler'] = evaluate_model(df_ohe, lasso, robust_scaler, tv='price')
results['OneHot encoding - Ridge - Robust Scaler'] = evaluate_model(df_ohe, ridge, robust_scaler, tv='price')
results['OneHot encoding - Elastic - Robust Scaler'] = evaluate_model(df_ohe, elastic, robust_scaler, tv='price')

# %%
pd.options.display.float_format = '{:,.4f}'.format
pd.DataFrame(results, index = ['MAE', 'MAE/Mean', 'MSE', 'R2']).T
# Out:
#                                                             MAE  \
# Count encoding - Linear - Standard Scaler               82.9655
# Count encoding - Lasso - Standard Scaler                82.7244
# Count encoding - Ridge - Standard Scaler                82.9632
# Count encoding - Elastic - Standard Scaler              82.6966
# Count encoding - Linear - Robust Scaler                 82.9655
# Count encoding - Lasso - Robust Scaler                  82.7244
# Count encoding - Ridge - Robust Scaler                  82.9632
# Count encoding - Elastic - Robust Scaler                82.6966
# OneHot encoding - Linear - Standard Scaler  92,696,615,199.4398
# OneHot encoding - Lasso - Standard Scaler               70.6589
# OneHot encoding - Ridge - Standard Scaler               71.1954
# OneHot encoding - Elastic - Standard Scaler             69.8900
# OneHot encoding - Linear - Robust Scaler    92,696,615,199.4398
# OneHot encoding - Lasso - Robust Scaler                 70.6589
# OneHot encoding - Ridge - Robust Scaler                 71.1954
# OneHot encoding - Elastic - Robust Scaler               69.8900
#
#                                                     MAE/Mean  \
# Count encoding - Linear - Standard Scaler             0.5481
# Count encoding - Lasso - Standard Scaler              0.5466
# Count encoding - Ridge - Standard Scaler              0.5481
# Count encoding - Elastic - Standard Scaler            0.5464
# Count encoding - Linear - Robust Scaler               0.5481
# Count encoding - Lasso - Robust Scaler                0.5466
# Count encoding - Ridge - Robust Scaler                0.5481
# Count encoding - Elastic - Robust Scaler              0.5464
# OneHot encoding - Linear - Standard Scaler  612,439,634.3291
# OneHot encoding - Lasso - Standard Scaler             0.4668
# OneHot encoding - Ridge - Standard Scaler             0.4704
# OneHot encoding - Elastic - Standard Scaler           0.4618
# OneHot encoding - Linear - Robust Scaler    612,439,634.3291
# OneHot encoding - Lasso - Robust Scaler               0.4668
# OneHot encoding - Ridge - Robust Scaler               0.4704
# OneHot encoding - Elastic - Robust Scaler             0.4618
#
#                                                                                 MSE  \
# Count encoding - Linear - Standard Scaler                               54,174.9141
# Count encoding - Lasso - Standard Scaler                                54,159.9963
# Count encoding - Ridge - Standard Scaler                                54,174.6987
# Count encoding - Elastic - Standard Scaler                              54,153.0410
# Count encoding - Linear - Robust Scaler                                 54,174.9141
# Count encoding - Lasso - Robust Scaler                                  54,159.9963
# Count encoding - Ridge - Robust Scaler                                  54,174.6987
# Count encoding - Elastic - Robust Scaler                                54,153.0410
# OneHot encoding - Linear - Standard Scaler  42,086,802,054,193,675,696,603,136.0000
# OneHot encoding - Lasso - Standard Scaler                               51,425.2888
# OneHot encoding - Ridge - Standard Scaler                               51,474.7581
# OneHot encoding - Elastic - Standard Scaler                             51,377.7375
# OneHot encoding - Linear - Robust Scaler    42,086,802,054,193,675,696,603,136.0000
# OneHot encoding - Lasso - Robust Scaler                                 51,425.2888
# OneHot encoding - Ridge - Robust Scaler                                 51,474.7581
# OneHot encoding - Elastic - Robust Scaler                               51,377.7375
#
#                                                                            R2
# Count encoding - Linear - Standard Scaler                              0.0520
# Count encoding - Lasso - Standard Scaler                               0.0523
# Count encoding - Ridge - Standard Scaler                               0.0520
# Count encoding - Elastic - Standard Scaler                             0.0524
# Count encoding - Linear - Robust Scaler                                0.0520
# Count encoding - Lasso - Robust Scaler                                 0.0523
# Count encoding - Ridge - Robust Scaler                                 0.0520
# Count encoding - Elastic - Robust Scaler                               0.0524
# OneHot encoding - Linear - Standard Scaler  -736,452,883,053,591,134,208.0000
# OneHot encoding - Lasso - Standard Scaler                              0.1001
# OneHot encoding - Ridge - Standard Scaler                              0.0993
# OneHot encoding - Elastic - Standard Scaler                            0.1010
# OneHot encoding - Linear - Robust Scaler    -736,452,883,053,591,134,208.0000
# OneHot encoding - Lasso - Robust Scaler                                0.1001
# OneHot encoding - Ridge - Robust Scaler                                0.0993
# OneHot encoding - Elastic - Robust Scaler                              0.1010

# %% [markdown]
# Видим, что с OneHot Encoding'ом линейная модель не справляется категорически, но и более продвинутые модели показывают низкие результаты. Поэтому, дополним таблицу результатами логарифмической целевой переменной.

# %% [markdown]
# ## Count Encoding - Standard Scaler - Log Price

# %%
results['Count encoding - Linear - Standard Scaler - LogPrice'] = evaluate_model(df_ce, lr, std_scaler, tv='price_log')

# %%
results['Count encoding - Lasso - Standard Scaler - LogPrice'] = evaluate_model(df_ce, lasso, std_scaler, tv='price_log')

# %%
results['Count encoding - Ridge - Standard Scaler - LogPrice'] = evaluate_model(df_ce, ridge, std_scaler, tv='price_log')

# %%
results['Count encoding - Elastic - Standard Scaler - LogPrice'] = evaluate_model(df_ce, elastic, std_scaler, tv='price_log')

# %% [markdown]
# ## Count Encoding - Robust Scaler - Log Price

# %%
results['Count encoding - Linear - Robust Scaler - Log Price'] = evaluate_model(df_ce, lr, robust_scaler, tv='price_log')

# %%
results['Count encoding - Lasso - Robust Scaler - Log Price'] = evaluate_model(df_ce, lasso, robust_scaler, tv='price_log')

# %%
results['Count encoding - Ridge - Robust Scaler - Log Price'] = evaluate_model(df_ce, ridge, robust_scaler, tv='price_log')

# %%
results['Count encoding - Elastic - Robust Scaler - Log Price'] = evaluate_model(df_ce, elastic, robust_scaler, tv='price_log')

# %% [markdown]
# ## OneHot Encoding - Standard Scaler - Log Price

# %%
results['OneHot encoding - Linear - Standard Scaler - Log Price'] = evaluate_model(df_ohe, lr, std_scaler, tv='price_log')

# %%
results['OneHot encoding - Lasso - Standard Scaler - Log Price'] = evaluate_model(df_ohe, lasso, std_scaler, tv='price_log')

# %%
results['OneHot encoding - Ridge - StandardScaler - Log Price'] = evaluate_model(df_ohe, ridge, std_scaler, tv='price_log')

# %%
results['OneHot encoding - Elastic - Standard Scaler - Log Price'] = evaluate_model(df_ohe, elastic, std_scaler, tv='price_log')

# %% [markdown]
# ## OneHot Encoding - Robust Scaler - Log Price

# %%
results['OneHot encoding - Linear - Robust Scaler - Log Price'] = evaluate_model(df_ohe, lr, robust_scaler, tv='price_log')

# %%
results['OneHot encoding - Lasso - Robust Scaler - Log Price'] = evaluate_model(df_ohe, lasso, robust_scaler, tv='price_log')

# %%
results['OneHot encoding - Ridge - Robust Scaler - Log Price'] = evaluate_model(df_ohe, ridge, robust_scaler, tv='price_log')

# %%
results['OneHot encoding - Elastic - Robust Scaler - Log Price'] = evaluate_model(df_ohe, elastic, robust_scaler, tv='price_log')

# %% [markdown]
# ## Посмотрим на сводную таблицу с результатами

# %%
pd.DataFrame(results, index = ['MAE', 'MAE/Mean', 'MSE', 'R2']).T
# Out:
#                                                                    MAE  \
# Count encoding - Linear - Standard Scaler                      82.9655
# Count encoding - Lasso - Standard Scaler                       82.7244
# Count encoding - Ridge - Standard Scaler                       82.9632
# Count encoding - Elastic - Standard Scaler                     82.6966
# Count encoding - Linear - Robust Scaler                        82.9655
# Count encoding - Lasso - Robust Scaler                         82.7244
# Count encoding - Ridge - Robust Scaler                         82.9632
# Count encoding - Elastic - Robust Scaler                       82.6966
# OneHot encoding - Linear - Standard Scaler         92,696,615,199.4398
# OneHot encoding - Lasso - Standard Scaler                      70.6589
# OneHot encoding - Ridge - Standard Scaler                      71.1954
# OneHot encoding - Elastic - Standard Scaler                    69.8900
# OneHot encoding - Linear - Robust Scaler           92,696,615,199.4398
# OneHot encoding - Lasso - Robust Scaler                        70.6589
# OneHot encoding - Ridge - Robust Scaler                        71.1954
# OneHot encoding - Elastic - Robust Scaler                      69.8900
# Count encoding - Linear - Standard Scaler - Log...              0.4407
# Count encoding - Lasso - Standard Scaler - LogP...              0.4407
# Count encoding - Ridge - Standard Scaler - LogP...              0.4407
# Count encoding - Elastic - Standard Scaler - Lo...              0.4407
# Count encoding - Linear - Robust Scaler - Log P...              0.4407
# Count encoding - Lasso - Robust Scaler - Log Price              0.4407
# Count encoding - Ridge - Robust Scaler - Log Price              0.4407
# Count encoding - Elastic - Robust Scaler - Log ...              0.4407
# OneHot encoding - Linear - Standard Scaler - Lo...    418,047,543.0096
# OneHot encoding - Lasso - Standard Scaler - Log...              0.3379
# OneHot encoding - Ridge - StandardScaler - Log ...              0.3384
# OneHot encoding - Elastic - Standard Scaler - L...              0.3379
# OneHot encoding - Linear - Robust Scaler - Log ...    418,047,543.0096
# OneHot encoding - Lasso - Robust Scaler - Log P...              0.3379
# OneHot encoding - Ridge - Robust Scaler - Log P...              0.3384
# OneHot encoding - Elastic - Robust Scaler - Log...              0.3379
#
#                                                            MAE/Mean  \
# Count encoding - Linear - Standard Scaler                    0.5481
# Count encoding - Lasso - Standard Scaler                     0.5466
# Count encoding - Ridge - Standard Scaler                     0.5481
# Count encoding - Elastic - Standard Scaler                   0.5464
# Count encoding - Linear - Robust Scaler                      0.5481
# Count encoding - Lasso - Robust Scaler                       0.5466
# Count encoding - Ridge - Robust Scaler                       0.5481
# Count encoding - Elastic - Robust Scaler                     0.5464
# OneHot encoding - Linear - Standard Scaler         612,439,634.3291
# OneHot encoding - Lasso - Standard Scaler                    0.4668
# OneHot encoding - Ridge - Standard Scaler                    0.4704
# OneHot encoding - Elastic - Standard Scaler                  0.4618
# OneHot encoding - Linear - Robust Scaler           612,439,634.3291
# OneHot encoding - Lasso - Robust Scaler                      0.4668
# OneHot encoding - Ridge - Robust Scaler                      0.4704
# OneHot encoding - Elastic - Robust Scaler                    0.4618
# Count encoding - Linear - Standard Scaler - Log...           0.0931
# Count encoding - Lasso - Standard Scaler - LogP...           0.0931
# Count encoding - Ridge - Standard Scaler - LogP...           0.0931
# Count encoding - Elastic - Standard Scaler - Lo...           0.0931
# Count encoding - Linear - Robust Scaler - Log P...           0.0931
# Count encoding - Lasso - Robust Scaler - Log Price           0.0931
# Count encoding - Ridge - Robust Scaler - Log Price           0.0931
# Count encoding - Elastic - Robust Scaler - Log ...           0.0931
# OneHot encoding - Linear - Standard Scaler - Lo...  88,297,921.5293
# OneHot encoding - Lasso - Standard Scaler - Log...           0.0714
# OneHot encoding - Ridge - StandardScaler - Log ...           0.0715
# OneHot encoding - Elastic - Standard Scaler - L...           0.0714
# OneHot encoding - Linear - Robust Scaler - Log ...  88,297,921.5293
# OneHot encoding - Lasso - Robust Scaler - Log P...           0.0714
# OneHot encoding - Ridge - Robust Scaler - Log P...           0.0715
# OneHot encoding - Elastic - Robust Scaler - Log...           0.0714
#
#                                                                                        MSE  \
# Count encoding - Linear - Standard Scaler                                      54,174.9141
# Count encoding - Lasso - Standard Scaler                                       54,159.9963
# Count encoding - Ridge - Standard Scaler                                       54,174.6987
# Count encoding - Elastic - Standard Scaler                                     54,153.0410
# Count encoding - Linear - Robust Scaler                                        54,174.9141
# Count encoding - Lasso - Robust Scaler                                         54,159.9963
# Count encoding - Ridge - Robust Scaler                                         54,174.6987
# Count encoding - Elastic - Robust Scaler                                       54,153.0410
# OneHot encoding - Linear - Standard Scaler         42,086,802,054,193,675,696,603,136.0000
# OneHot encoding - Lasso - Standard Scaler                                      51,425.2888
# OneHot encoding - Ridge - Standard Scaler                                      51,474.7581
# OneHot encoding - Elastic - Standard Scaler                                    51,377.7375
# OneHot encoding - Linear - Robust Scaler           42,086,802,054,193,675,696,603,136.0000
# OneHot encoding - Lasso - Robust Scaler                                        51,425.2888
# OneHot encoding - Ridge - Robust Scaler                                        51,474.7581
# OneHot encoding - Elastic - Robust Scaler                                      51,377.7375
# Count encoding - Linear - Standard Scaler - Log...                                  0.3440
# Count encoding - Lasso - Standard Scaler - LogP...                                  0.3440
# Count encoding - Ridge - Standard Scaler - LogP...                                  0.3440
# Count encoding - Elastic - Standard Scaler - Lo...                                  0.3440
# Count encoding - Linear - Robust Scaler - Log P...                                  0.3440
# Count encoding - Lasso - Robust Scaler - Log Price                                  0.3440
# Count encoding - Ridge - Robust Scaler - Log Price                                  0.3440
# Count encoding - Elastic - Robust Scaler - Log ...                                  0.3440
# OneHot encoding - Linear - Standard Scaler - Lo...        854,796,936,008,146,223,104.0000
# OneHot encoding - Lasso - Standard Scaler - Log...                                  0.2233
# OneHot encoding - Ridge - StandardScaler - Log ...                                  0.2236
# OneHot encoding - Elastic - Standard Scaler - L...                                  0.2233
# OneHot encoding - Linear - Robust Scaler - Log ...        854,796,936,008,146,223,104.0000
# OneHot encoding - Lasso - Robust Scaler - Log P...                                  0.2233
# OneHot encoding - Ridge - Robust Scaler - Log P...                                  0.2236
# OneHot encoding - Elastic - Robust Scaler - Log...                                  0.2233
#
#                                                                                     R2
# Count encoding - Linear - Standard Scaler                                       0.0520
# Count encoding - Lasso - Standard Scaler                                        0.0523
# Count encoding - Ridge - Standard Scaler                                        0.0520
# Count encoding - Elastic - Standard Scaler                                      0.0524
# Count encoding - Linear - Robust Scaler                                         0.0520
# Count encoding - Lasso - Robust Scaler                                          0.0523
# Count encoding - Ridge - Robust Scaler                                          0.0520
# Count encoding - Elastic - Robust Scaler                                        0.0524
# OneHot encoding - Linear - Standard Scaler           -736,452,883,053,591,134,208.0000
# OneHot encoding - Lasso - Standard Scaler                                       0.1001
# OneHot encoding - Ridge - Standard Scaler                                       0.0993
# OneHot encoding - Elastic - Standard Scaler                                     0.1010
# OneHot encoding - Linear - Robust Scaler             -736,452,883,053,591,134,208.0000
# OneHot encoding - Lasso - Robust Scaler                                         0.1001
# OneHot encoding - Ridge - Robust Scaler                                         0.0993
# OneHot encoding - Elastic - Robust Scaler                                       0.1010
# Count encoding - Linear - Standard Scaler - Log...                              0.2751
# Count encoding - Lasso - Standard Scaler - LogP...                              0.2751
# Count encoding - Ridge - Standard Scaler - LogP...                              0.2751
# Count encoding - Elastic - Standard Scaler - Lo...                              0.2751
# Count encoding - Linear - Robust Scaler - Log P...                              0.2751
# Count encoding - Lasso - Robust Scaler - Log Price                              0.2751
# Count encoding - Ridge - Robust Scaler - Log Price                              0.2751
# Count encoding - Elastic - Robust Scaler - Log ...                              0.2751
# OneHot encoding - Linear - Standard Scaler - Lo... -1,801,366,288,371,461,390,336.0000
# OneHot encoding - Lasso - Standard Scaler - Log...                              0.5295
# OneHot encoding - Ridge - StandardScaler - Log ...                              0.5288
# OneHot encoding - Elastic - Standard Scaler - L...                              0.5294
# OneHot encoding - Linear - Robust Scaler - Log ... -1,801,366,288,371,461,390,336.0000
# OneHot encoding - Lasso - Robust Scaler - Log P...                              0.5295
# OneHot encoding - Ridge - Robust Scaler - Log P...                              0.5288
# OneHot encoding - Elastic - Robust Scaler - Log...                              0.5294

# %% [markdown]
# Видим, что с предсказанием логарифмической целевой переменной модели справляются на два порядка лучше (за исключением базовой модели линейной регрессии, здесь наблюдается полный провал), а самые лучшие результаты показывают продвинутые линейные модели вместе с использованием OneHot Encoding'a, при этом существенные отличия между использованием Standard Scaler'a и Robust Scaler'а отсутствуют.
